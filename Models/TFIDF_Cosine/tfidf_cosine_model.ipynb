# %%
import pandas as pd

# %%
#Read Dataset
df_combined = pd.read_csv("../../Datasets/processed_data.csv")

# %%
df_combined.shape
# Out:
# (6243, 11)

# %%
#Overview of dataset
df_combined.head()
# Out:
#                                                  url  \
# 0  https://www.mycareersfuture.gov.sg/job/custome...
# 1  https://www.mycareersfuture.gov.sg/job/enginee...
# 2  https://www.mycareersfuture.gov.sg/job/sales/b...
# 3  https://www.mycareersfuture.gov.sg/job/banking...
# 4  https://www.mycareersfuture.gov.sg/job/archite...
#
#                                            job_title  \
# 0                         PRODUCTION CONTROL MANAGER
# 1       Design Engineer ( Mechanical  /  Electrical)
# 2                     Business Development Executive
# 3                            Senior / Data Scientist
# 4  8890-Sales Consultant [ Digital Software| Saas...
#
#                                     description_html  \
# 0  <p><strong>JOB DESCIPTION</strong></p>\n<ul>\n...
# 1  <p><strong>SUMMARY</strong></p>\n<ul>\n  <li>T...
# 2  <p><strong>Job description</strong></p>\n<p>Wh...
# 3  <p>The ideal candidate should have a good unde...
# 4  <p><strong>Sales Consultant (Digital Software)...
#
#                                          description               pay_range  \
# 0  JOB DESCIPTION\n\n  planning and organising pr...     $2,000   - $3,400
# 1  SUMMARY\n\n  This      position is responsible...     $2,500   - $4,500
# 2  Job description\nWho we are:\nWe are a logisti...     $3,200   - $3,500
# 3  The ideal candidate should have a good underst...    $9,000   - $14,000
# 4  Sales Consultant (Digital Software)\nLocation:...     $3,000   - $4,500
#
#                job_type                                            company  \
# 0  Permanent, Full Time                              Snl Logistics Pte Ltd
# 1             Full Time  Jamco Aero Design &Amp; Engineering Private Li...
# 2  Part Time, Permanent                             Airpak Express Pte Ltd
# 3  Permanent, Full Time                         Singapore Exchange Limited
# 4  Permanent, Full Time                  The Supreme Hr Advisory Pte. Ltd.
#
#                                             location  \
# 0                               31 GUL CIRCLE 629569
# 1                                                NaN
# 2  TECHPLAS INDUSTRIAL BUILDING, 45 CHANGI SOUTH ...
# 3                 SGX CENTRE I, 2 SHENTON WAY 068804
# 4                SHENTON HOUSE, 3 SHENTON WAY 068805
#
#                                   description_tokens  \
# 0  ['job', 'descipt', 'plan', 'organis', 'product...
# 1  ['summari', 'posit', 'respons', 'support', 'pr...
# 2  ['job', 'descript', 'logist', 'servic', 'provi...
# 3  ['ideal', 'candid', 'good', 'understand', 'bus...
# 4  ['sale', 'consult', 'digit', 'softwar', 'locat...
#
#                                     full_info_tokens  duplicated
# 0  ['product', 'control', 'manag', 'job', 'descip...       False
# 1  ['design', 'engin', 'mechan', 'electr', 'summa...       False
# 2  ['busi', 'develop', 'execut', 'job', 'descript...       False
# 3  ['senior', 'data', 'scientist', 'ideal', 'cand...       False
# 4  ['8890', 'sale', 'consult', 'digit', 'softwar'...       False

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#Set ngram range to 2 to include phrases
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))

# %%
#Fit full_info_tokens onto the tfidf vectorizer
tfidf_job = tfidf_vectorizer.fit_transform(df_combined['full_info_tokens'])

# %%
#Check if tfidf_vectorizer worked correctly
tfidf_vectorizer.vocabulary_
# Out:
# {'product': 256779,
#  'control': 75442,
#  'manag': 199474,
#  'job': 179027,
#  'descipt': 93362,
#  'plan': 243525,
#  'organis': 230745,
#  'schedul': 293705,
#  'assess': 30745,
#  'project': 260458,
#  'resourc': 282838,
#  'requir': 280306,
#  'estim': 119370,
#  'negoti': 219145,
#  'agre': 16032,
#  'budget': 45753,
#  'timelin': 339248,
#  'client': 58992,
#  'ensur': 114869,
#  'health': 153032,
#  'safeti': 291085,
#  'regul': 275660,
#  'met': 208243,
#  'determin': 95717,
#  'qualiti': 266785,
#  'standard': 316626,
#  'overse': 233061,
#  'process': 255382,
#  'select': 298107,
#  'order': 229842,
#  'purchas': 264780,
#  'materi': 204138,
#  'repair': 278694,
#  'routin': 289869,
#  'mainten': 198235,
#  'equip': 117528,
#  'liais': 190896,
#  'buyer': 48058,
#  'supervis': 324315,
#  'day': 87139,
#  'work': 364678,
#  'junior': 180897,
#  'staff': 315544,
#  'worker': 366159,
#  'factori': 129929,
#  'environ': 116494,
#  'relev': 277456,
#  'train': 343004,
#  'session': 301090,
#  'goal': 146422,
#  'within': 363761,
#  'approv': 27425,
#  'min': 210466,
#  'diploma': 99117,
#  'year': 368840,
#  'supervisori': 324576,
#  'experi': 124790,
#  'similar': 304441,
#  'industri': 165867,
#  'manufactu': 202018,
#  'pc': 238538,
#  'liter': 193950,
#  'well': 361790,
#  'organ': 230184,
#  'team': 330822,
#  'player': 245203,
#  'will': 363251,
#  'west': 362514,
#  'area': 28502,
#  'compani': 66049,
#  'transport': 344692,
#  'pioneer': 242730,
#  'choa': 57078,
#  'chu': 57230,
#  'kang': 181340,
#  'mrt': 215718,
#  'extens': 128501,
#  'knowledg': 182795,
#  'snl': 308569,
#  'logist': 195433,
#  'pte': 264368,
#  'ltd': 196686,
#  'product control': 257020,
#  'control manag': 75729,
#  'manag job': 200311,
#  'job descipt': 179142,
#  'descipt plan': 93363,
#  'plan organis': 243920,
#  'organis product': 230969,
#  'product schedul': 257745,
#  'schedul assess': 293728,
#  'assess project': 30971,
#  'project resourc': 261172,
#  'resourc requir': 283095,
#  'requir estim': 280671,
#  'estim negoti': 119428,
#  'negoti agre': 219148,
#  'agre budget': 16042,
#  'budget timelin': 45912,
#  'timelin client': 339264,
#  'client ensur': 59257,
#  'ensur health': 115163,
#  'health safeti': 153183,
#  'safeti regul': 291235,
#  'regul met': 275815,
#  'met determin': 208268,
#  'determin qualiti': 95829,
#  'qualiti control': 266891,
#  'control standard': 75903,
#  'standard overse': 316904,
#  'overse product': 233161,
#  'product process': 257628,
#  'process select': 256222,
#  'select order': 298199,
#  'order purchas': 230016,
#  'purchas materi': 264819,
#  'materi organis': 204290,
#  'organis repair': 230989,
#  'repair routin': 278741,
#  'routin mainten': 289905,
#  'mainten product': 198469,
#  'product equip': 257158,
#  'equip liais': 117667,
#  'liais buyer': 190913,
#  'buyer supervis': 48078,
#  'supervis manag': 324411,
#  'manag day': 199899,
#  'day day': 87253,
#  'day work': 87492,
#  'work junior': 365382,
#  'junior staff': 180971,
#  'staff product': 315707,
#  'product worker': 257987,
#  'worker factori': 366177,
#  'factori environ': 129945,
#  'environ organis': 117012,
#  'organis relev': 230987,
#  'relev train': 277833,
#  'train session': 343408,
#  'session ensur': 301126,
#  'ensur project': 115351,
#  'project goal': 260837,
#  'goal met': 146612,
#  'met within': 208335,
#  'within approv': 363797,
#  'approv budget': 27444,
#  'budget requir': 45883,
#  'requir min': 280943,
#  'min diploma': 210479,
#  'diploma manag': 99180,
#  'manag min': 200452,
#  'min year': 210501,
#  'year supervisori': 369276,
#  'supervisori experi': 324583,
#  'experi year': 126518,
#  'year experi': 369017,
#  'experi similar': 126223,
#  'similar industri': 304493,
#  'industri manufactu': 166269,
#  'manufactu pc': 202019,
#  'pc liter': 238554,
#  'liter well': 193966,
#  'well organ': 362232,
#  'organ team': 230683,
#  'team player': 331824,
#  'player will': 245468,
#  'will work': 363324,
#  'work west': 366059,
#  'west area': 362519,
#  'area compani': 28597,
#  'compani transport': 66805,
#  'transport pioneer': 344759,
#  'pioneer choa': 242740,
#  'choa chu': 57079,
#  'chu kang': 57234,
#  'kang mrt': 181345,
#  'mrt extens': 215731,
#  'extens knowledg': 128553,
#  'knowledg safeti': 183596,
#  'safeti process': 291223,
#  'process snl': 256251,
#  'snl logist': 308570,
#  'logist pte': 195521,
#  'pte ltd': 264371,
#  'design': 93896,
#  'engin': 112793,
#  'mechan': 206018,
#  'electr': 109144,
#  'summari': 323948,
#  'posit': 247685,
#  'respons': 283447,
#  'support': 324859,
#  'senior': 298762,
#  'level': 189985,
#  'research': 281523,
#  'substanti': 322908,
#  'payload': 238141,
#  'system': 327197,
#  'structur': 321458,
#  'depart': 92093,
#  'util': 353458,
#  'establish': 118976,
#  'model': 212497,
#  'draft': 103614,
#  'develop': 95931,
#  'aircraft': 17011,
#  'packag': 234254,
#  'base': 38194,
#  'custom': 82663,
#  'retrofit': 285528,
#  'applic': 25722,
#  'essenti': 118802,
#  'duti': 105213,
#  'responsibilit': 284339,
#  'includ': 163041,
#  'follow': 136861,
#  'assign': 31328,
#  'perform': 239546,
#  'accord': 8097,
#  'lead': 186862,
#  'task': 330042,
#  'limit': 192631,
#  'basic': 39131,
#  'instal': 170383,
#  'detail': 95122,
#  'assembl': 30673,
#  'specif': 313241,
#  'direct': 99228,
#  'experienc': 126530,
#  'maintain': 197706,
#  'modifi': 213551,
#  'defin': 89429,
#  'use': 351929,
#  'tool': 340357,
#  'particip': 235877,
#  'document': 102306,
#  'implement': 161127,
#  'obtain': 223852,
#  'interpret': 174457,
#  'analyz': 22947,
#  'oem': 224171,
#  'airplan': 17104,
#  'draw': 103705,
#  'troubleshoot': 345816,
#  'problem': 254613,
#  'activ': 10757,
#  'initi': 168274,
#  'coordin': 76449,
#  'necessari': 218231,
#  'intern': 173417,
#  'per': 239368,
#  'regulatori': 276097,
#  'agenc': 15350,
#  'domest': 103159,
#  'travel': 344800,
#  'may': 205123,
#  'qualif': 266363,
#  'success': 323037,
#  'individu': 165456,
#  'must': 216825,
#  'abl': 6737,
#  'list': 193731,
#  'repres': 279747,
#  'skill': 306589,
#  'abil': 6207,
#  'qualifi': 266653,
#  'degre': 89836,
#  'aerospac': 14930,
#  'relat': 276384,
#  'field': 132387,
#  'aviat': 35536,
#  'practic': 249802,
#  'scienc': 294254,
#  'technolog': 333627,
#  'appli': 25199,
#  'principl': 253348,
#  'techniqu': 333259,
#  'procedur': 255103,
#  'variou': 355225,
#  'good': 146856,
#  'servic': 300079,
#  'read': 271358,
#  'understand': 347913,
#  'comput': 69264,
#  'aid': 16712,
#  'cad': 48381,
#  'involv': 175968,
#  'precis': 250461,
#  'technic': 332787,
#  'administr': 12924,
#  'accept': 7568,
#  'role': 288686,
#  'account': 8325,
#  'solv': 310792,
#  'identifi': 159280,
#  'complex': 67947,
#  'review': 285914,
#  'inform': 166988,
#  'evalu': 120522,
#  'option': 229484,
#  'solut': 309738,
#  'critic': 80709,
#  'think': 337132,
#  'logic': 195294,
#  'reason': 271857,
#  'strength': 320683,
#  'weak': 360788,
#  'altern': 19090,
#  'conclus': 70234,
#  'approach': 26829,
#  'scientif': 294775,
#  'rule': 290189,
#  'method': 208470,
#  'mathemat': 204434,
#  'concept': 69661,
#  'measur': 205735,
#  'fraction': 139236,
#  'percentag': 239480,
#  'ratio': 270866,
#  'trigonometri': 345714,
#  'imaginari': 160355,
#  'number': 222703,
#  'proport': 262082,
#  'formula': 138567,
#  'embed': 109938,
#  'linkag': 193453,
#  'amongst': 19955,
#  'cell': 53048,
#  'spreadsheet': 314347,
#  'program': 259152,
#  'orient': 231180,
#  'demonstr': 91731,
#  'concern': 70082,
#  'take': 328972,
#  'action': 10469,
#  'meet': 206637,
#  'high': 154399,
#  'extern': 128621,
#  'display': 100893,
#  'courtesi': 78617,
#  'sensit': 299136,
#  'difficult': 98466,
#  'situat': 306332,
#  'commit': 64754,
#  'respond': 283354,
#  'promptli': 261749,
#  'need': 218478,
#  'solicit': 309600,
#  'feedback': 131828,
#  'improv': 162056,
#  'commun': 65289,
#  'give': 145159,
#  'full': 140833,
#  'attent': 33148,
#  'peopl': 238953,
#  'say': 292747,
#  'time': 338546,
#  'point': 246395,
#  'made': 197371,
#  'ask': 30325,
#  'question': 268072,
#  'appropri': 27158,
#  'interrupt': 174585,
#  'inappropri': 162745,
#  'effect': 107566,
#  'write': 367759,
#  'audienc': 33609,
#  'talk': 329577,
#  'other': 231741,
#  'convey': 76230,
#  'oral': 229737,
#  'written': 368051,
#  'languag': 185276,
#  'gener': 143813,
#  'busi': 46972,
#  'period': 240395,
#  'data': 84769,
#  'government': 147789,
#  'formal': 138182,
#  'correspond': 77529,
#  'judgment': 180752,
#  'decis': 88516,
#  'make': 198752,
#  'consid': 71975,
#  'rel': 276362,
#  'cost': 77622,
#  'benefit': 40666,
#  'potenti': 248955,
#  'choos': 57151,
#  'one': 225757,
#  'multitask': 216621,
#  'independ': 164838,
#  'attitud': 33211,
#  'continu': 74464,
#  'profession': 258085,
#  'jamco': 178013,
#  'aero': 14920,
#  'amp': 20020,
#  'privat': 254261,
#  'design engin': 94175,
#  'engin mechan': 113450,
#  'mechan electr': 206054,
#  'electr summari': 109222,
#  'summari posit': 324029,
#  'posit respons': 248104,
#  'respons support': 284237,
#  'support project': 325704,
#  'project team': 261297,
#  'team senior': 332007,
#  'senior level': 298887,
#  'level engin': 190149,
#  'engin research': 113696,
#  'research design': 281708,
#  'design substanti': 94640,
#  'substanti electr': 322918,
#  'electr mechan': 109193,
#  'mechan payload': 206099,
#  'payload system': 238143,
#  'system structur': 328168,
#  'structur design': 321543,
#  'design within': 94722,
#  'within engin': 363950,
#  'engin depart': 113099,
#  'depart util': 92455,
#  'util establish': 353512,
#  'establish process': 119194,
#  'process model': 255971,
#  'model draft': 212743,
#  'draft standard': 103674,
#  'standard design': 316747,
#  'engin support': 113831,
#  'support design': 325167,
#  'design develop': 94130,
#  'develop aircraft': 95992,
#  'aircraft engin': 17015,
#  'engin packag': 113551,
#  'packag base': 234276,
#  'base custom': 38347,
#  'custom requir': 83292,
#  'requir product': 281089,
#  'product retrofit': 257714,
#  'retrofit applic': 285529,
#  'applic product': 26382,
#  'product develop': 257093,
#  'develop essenti': 96378,
#  'essenti duti': 118838,
#  'duti responsibilit': 105335,
#  'responsibilit includ': 284343,
#  'includ follow': 163464,
#  'follow duti': 137012,
#  'duti assign': 105222,
#  'assign perform': 31492,
#  'perform design': 239764,
#  'design assign': 93967,
#  'assign accord': 31335,
#  'accord establish': 8153,
#  'establish design': 119066,
#  'design standard': 94621,
#  'standard supervis': 317016,
#  'supervis lead': 324404,
#  'lead senior': 187454,
#  'senior engin': 298823,
#  'engin assign': 112912,
#  'assign design': 31399,
#  'design task': 94654,
#  'task includ': 330193,
#  'includ limit': 163638,
#  'limit basic': 192669,
#  'basic aircraft': 39160,
#  'aircraft design': 17014,
#  'design electr': 94161,
#  'mechan structur': 206130,
#  'structur payload': 321663,
#  'system instal': 327722,
#  'instal detail': 170413,
#  'detail assembl': 95154,
#  'assembl system': 30722,
#  'system specif': 328148,
#  'specif work': 313658,
#  'work direct': 365050,
#  'direct experienc': 99338,
#  'experienc engin': 126604,
#  'engin maintain': 113426,
#  'maintain modifi': 197993,
#  'modifi basic': 213554,
#  'basic electr': 39208,
#  'system base': 327305,
#  'base defin': 38357,
#  'defin requir': 89639,
#  'requir use': 281373,
#  'use approv': 351992,
#  'approv process': 27528,
#  'process tool': 256347,
#  'tool particip': 340854,
#  'particip project': 236127,
#  'team support': 332110,
#  'support develop': 325173,
#  'develop design': 96299,
#  'design support': 94644,
#  'support document': 325191,
#  'document design': 102457,
#  'design implement': 94291,
#  'implement obtain': 161559,
#  'obtain interpret': 223885,
#  'interpret analyz': 174464,
#  'analyz oem': 23104,
#  'oem airplan': 224173,
#  'airplan instal': 17105,
#  'instal draw': 170415,
#  'draw use': 103786,
#  'tool troubleshoot': 341082,
#  'troubleshoot basic': 345831,
#  'basic mechan': 39255,
#  'system problem': 327979,
#  'problem activ': 254627,
#  'activ support': 11313,
#  'support engin': 325232,
#  'depart project': 92373,
#  'team goal': 331453,
#  'goal initi': 146578,
#  'initi coordin': 168385,
#  'coordin depart': 76537,
#  'depart necessari': 92332,
#  'necessari util': 218451,
#  'util intern': 353537,
#  'intern draw': 173606,
#  'draw document': 103731,
#  'document standard': 102770,
#  'standard per': 316913,
#  'per custom': 239389,
#  'custom regulatori': 83284,
#  'regulatori agenc': 276105,
#  'agenc requir': 15521,
#  'requir domest': 280616,
#  'domest intern': 103169,
#  'intern travel': 174022,
#  'travel may': 344876,
#  'may requir': 205288,
#  'requir qualif': 281113,
#  'qualif perform': 266551,
#  'perform job': 239959,
#  'job success': 179444,
#  'success individu': 323228,
#  'individu must': 165665,
#  'must abl': 216831,
#  'abl perform': 6953,
#  'perform essenti': 239820,
#  'duti direct': 105249,
#  'engin establish': 113176,
#  'establish depart': 119065,
#  'depart standard': 92420,
#  'standard process': 316936,
#  'process requir': 256182,
#  'requir list': 280897,
#  'list repres': 193862,
#  'repres knowledg': 279821,
#  'knowledg skill': 183636,
#  'skill abil': 306597,
#  'abil requir': 6621,
#  'requir requir': 281164,
#  'requir qualifi': 281114,
#  'qualifi degre': 266670,
#  'degre mechan': 90032,
#  'electr engin': 109169,
#  'engin aerospac': 112855,
#  'aerospac engin': 14940,
#  'engin relat': 113684,
#  'relat engin': 276568,
#  'engin field': 113217,
#  'field year': 132758,
#  'experi engin': 125301,
#  'engin aviat': 112927,
#  'aviat relat': 35558,
#  'relat field': 276595,
#  'field knowledg': 132569,
#  'knowledg engin': 183092,
#  'engin knowledg': 113381,
#  'knowledg practic': 183496,
#  'practic applic': 249829,
#  'applic engin': 26016,
#  'engin scienc': 113722,
#  'scienc technolog': 294713,
#  'technolog includ': 334106,
#  'includ appli': 163108,
#  'appli principl': 25555,
#  'principl techniqu': 253526,
#  'techniqu procedur': 333512,
#  'procedur equip': 255184,
#  'equip design': 117599,
#  'design product': 94496,
#  'product variou': 257943,
#  'variou system': 355583,
#  'system good': 327647,
#  'good servic': 147204,
#  'servic design': 300345,
#  'design abl': 93903,
#  'abl read': 6984,
#  'read understand': 271427,
#  'understand comput': 348083,
#  'comput aid': 69271,
#  'aid design': 16725,
#  'design cad': 94004,
#  'cad design': 48384,
#  'design draw': 94149,
#  'draw specif': 103774,
#  'specif knowledg': 313456,
#  'knowledg design': 183037,
#  'design techniqu': 94660,
#  'techniqu tool': 333587,
#  'tool principl': 340892,
#  'principl involv': 253446,
#  'involv product': 176222,
#  'product precis': 257608,
#  'precis technic': 250508,
#  'technic plan': 333068,
#  'plan draw': 243721,
#  'draw model': 103753,
#  'model administr': 212518,
#  'administr abl': 12930,
#  'abl work': 7070,
#  'work team': 365949,
#  'team environ': 331315,
#  'environ accept': 116505,
#  'accept requir': 7646,
#  'requir role': 281183,
#  'role respons': 289300,
#  'respons account': 283459,
#  'account skill': 8681,
#  'skill problem': 307333,
#  'problem solv': 255012,
#  'solv identifi': 310924,
#  'identifi complex': 159351,
#  'complex problem': 68151,
#  'problem review': 254982,
#  'review relat': 286309,
#  'relat inform': 276648,
#  'inform develop': 167146,
#  'develop evalu': 96383,
#  'evalu option': 120732,
#  'option implement': 229541,
#  'implement solut': 161720,
#  'solut critic': 309971,
#  'critic think': 80904,
#  'think use': 337373,
#  'use logic': 352404,
#  'logic reason': 195396,
#  'reason identifi': 271892,
#  'identifi strength': 159638,
#  'strength weak': 320727,
#  'weak altern': 360791,
#  'altern solut': 19152,
#  'solut conclus': 309937,
#  'conclus approach': 70238,
#  'approach problem': 27058,
#  'problem use': 255072,
#  'use scientif': 352644,
#  'scientif rule': 294849,
#  'rule method': 290255,
#  'method solv': 208712,
#  'solv problem': 311006,
#  'problem requir': 254973,
#  'requir mathemat': 280924,
#  'mathemat abil': 204435,
#  'abil work': 6732,
#  'work mathemat': 365457,
#  'mathemat concept': 204461,
#  'concept measur': 69843,
#  'measur appli': 205755,
#  'appli concept': 25296,
#  'concept fraction': 69782,
#  'fraction percentag': 139240,
#  'percentag ratio': 239483,
#  'ratio trigonometri': 270880,
#  'trigonometri imaginari': 345715,
#  'imaginari number': 160356,
#  'number proport': 222851,
#  'proport abil': 262083,
#  'abil use': 6717,
#  'use variou': 352806,
#  'variou formula': 355379,
#  'formula embed': 138575,
#  'embed linkag': 109976,
#  'linkag amongst': 193456,
#  'amongst cell': 19957,
#  'cell spreadsheet': 53077,
#  'spreadsheet program': 314367,
#  'program custom': 259328,
#  'custom orient': 83188,
#  'orient must': 231349,
#  'must demonstr': 216901,
#  'demonstr concern': 91776,
#  'concern take': 70139,
#  'take action': 328981,
#  'action meet': 10628,
#  'meet requir': 206902,
#  'requir high': 280787,
#  'high standard': 154545,
#  'standard qualiti': 316952,
#  'qualiti intern': 267033,
#  'intern extern': 173655,
#  'extern custom': 128681,
#  'custom must': 83157,
#  'must display': 216907,
#  'display courtesi': 100900,
#  'courtesi sensit': 78618,
#  'sensit manag': 299174,
#  'manag difficult': 199940,
#  'difficult situat': 98487,
#  'situat meet': 306392,
#  'meet commit': 206690,
#  'commit respond': 64932,
#  'respond promptli': 283418,
#  'promptli custom': 261754,
#  'custom need': 83160,
#  'need solicit': 219028,
#  'solicit custom': 309602,
#  'custom feedback': 82984,
#  'feedback improv': 131931,
#  'improv servic': 162581,
#  'servic commun': 300274,
#  'commun give': 65587,
#  'give full': 145203,
#  'full attent': 140841,
#  'attent peopl': 33185,
#  'peopl say': 239259,
#  'say take': 292756,
#  'take time': 329205,
#  'time understand': 339162,
#  'understand point': 348546,
#  'point made': 246520,
#  'made ask': 197375,
#  'ask question': 30365,
#  'question appropri': 268080,
#  'appropri interrupt': 27288,
#  'interrupt inappropri': 174587,
#  'inappropri time': 162748,
#  'time commun': 338652,
#  'commun effect': 65497,
#  'effect write': 108057,
#  'write appropri': 367780,
#  'appropri need': 27326,
#  'need audienc': 218546,
#  'audienc talk': 33755,
#  'talk other': 329593,
#  'other convey': 231785,
#  'convey inform': 76245,
#  'inform effect': 167172,
#  'effect good': 107763,
#  'good oral': 147121,
#  'oral written': 229767,
#  'written commun': 368075,
#  'commun skill': 65892,
#  'skill languag': 307135,
#  'languag abil': 185278,
#  'abil read': 6605,
#  'read analyz': 271364,
#  'analyz interpret': 23064,
#  'interpret gener': 174504,
#  'gener busi': 143872,
#  'busi period': 47622,
#  'period procedur': 240514,
#  'procedur draw': 255174,
#  'draw technic': 103778,
#  'technic data': 332880,
#  'data engin': 85142,
#  'engin document': 113126,
#  'document government': 102525,
#  'government regul': 147791,
#  'regul abil': 275663,
#  'abil write': 6733,
#  'write engin': 367854,
#  'document formal': 102512,
#  'formal busi': 138186,
#  'busi correspond': 47186,
#  'correspond judgment': 77547,
#  'judgment decis': 180764,
#  'decis make': 88694,
#  'make consid': 198844,
#  'consid rel': 72096,
#  'rel cost': 276365,
#  'cost benefit': 77641,
#  'benefit potenti': 40862,
#  'potenti action': 248960,
#  'action choos': 10502,
#  'choos appropri': 57156,
#  'appropri one': 27329,
#  'one time': 226158,
#  'time manag': 338890,
#  'manag manag': 200402,
#  'manag one': 200529,
#  'time abl': 338566,
#  'abl multitask': 6939,
#  'multitask work': 216667,
#  'work independ': 365318,
#  'independ attitud': 164870,
#  'attitud demonstr': 33253,
#  'demonstr continu': 91780,
#  'continu skill': 74649,
#  'skill improv': 307064,
#  'improv profession': 162508,
#  'profession posit': 258338,
#  'posit attitud': 247724,
#  'attitud requir': 33342,
#  'requir jamco': 280855,
#  'jamco aero': 178014,
#  'aero design': 14921,
#  'design amp': 93937,
#  'amp engin': 20044,
#  'engin privat': 113607,
#  'privat limit': 254289,
#  'execut': 123092,
#  'descript': 93408,
#  'provid': 263201,
#  'solid': 309613,
#  'infrastructur': 167734,
#  'foundat': 138967,
#  'built': 46751,
#  'decad': 88416,
#  'constantli': 72582,
#  'move': 215410,
#  'ahead': 16245,
#  'trend': 345192,
#  'remain': 278124,
#  'headquart': 152968,
#  'singapor': 305016,
#  'proudli': 263080,
#  'singaporean': 305806,
#  'outreach': 232521,
#  'fresh': 140170,
#  'grad': 148051,
#  'keen': 181482,
#  'interest': 172743,
#  'welcom': 361658,
#  'learner': 189027,
#  'knack': 182555,
#  'flexibl': 135395,
#  'fast': 130874,
#  'pace': 233983,
#  'energet': 112094,
#  'competit': 67269,
#  'salari': 291360,
#  'growth': 149965,
#  'segment': 297875,
#  'target': 329772,
#  'analys': 20161,
#  'recommend': 272543,
#  'propos': 262085,
#  'end': 111711,
#  'price': 252809,
#  'quotat': 268559,
#  'submiss': 322571,
#  'ownership': 233739,
#  'payment': 238144,
#  'collect': 62961,
#  'exist': 123898,
#  'explor': 127739,
#  'new': 220121,
#  'opportun': 228117,
#  'strong': 320980,
#  'relationship': 276978,
#  'collat': 62624,
#  'market': 202704,
#  'competitor': 67431,
#  'intellig': 171887,
#  'interact': 172406,
#  'partner': 236400,
#  'entiti': 116105,
#  'long': 195638,
#  'term': 335348,
#  'clientel': 59838,
#  'leverag': 190562,
#  'expertis': 127179,
#  'suppli': 324614,
#  'chain': 54392,
#  'candid': 49308,
#  'possess': 248247,
#  'least': 189188,
#  'advanc': 13533,
#  'higher': 154581,
#  'graduat': 148144,
#  'english': 113966,
#  'airpak': 17102,
#  'express': 128332,
#  'busi develop': 47233,
#  'develop execut': 96393,
#  'execut job': 123409,
#  'job descript': 179143,
#  'descript logist': 93624,
#  'logist servic': 195533,
#  'servic provid': 300756,
#  'provid solid': 263914,
#  'solid infrastructur': 309660,
#  'infrastructur foundat': 167874,
#  'foundat built': 138983,
#  'built decad': 46776,
#  'decad experi': 88422,
#  'experi constantli': 125121,
#  'constantli move': 72621,
#  'move ahead': 215414,
#  'ahead logist': 16262,
#  'logist trend': 195554,
#  'trend remain': 345465,
#  'remain relev': 278170,
#  'relev headquart': 277612,
#  'headquart singapor': 153005,
#  'singapor proudli': 305613,
#  'proudli singaporean': 263085,
#  'singaporean intern': 305826,
#  'intern outreach': 173830,
#  'outreach fresh': 232528,
#  'fresh grad': 140184,
#  'grad keen': 148058,
#  'keen interest': 181522,
#  'interest logist': 172943,
#  'logist industri': 195484,
#  'industri welcom': 166563,
#  'welcom experi': 361694,
#  'experi requir': 126107,
#  'requir train': 281343,
#  'train provid': 343348,
#  'provid keen': 263639,
#  'keen learner': 181528,
#  'learner knack': 189080,
#  'knack appli': 182557,
#  'appli knowledg': 25457,
#  'knowledg flexibl': 183143,
#  'flexibl fast': 135456,
#  'fast pace': 130936,
#  'pace energet': 234015,
#  'energet environ': 112113,
#  'environ competit': 116651,
#  'competit salari': 67394,
#  'salari packag': 291477,
#  'packag growth': 234343,
#  'growth segment': 150286,
#  'segment industri': 297964,
#  'industri respons': 166424,
#  'respons identifi': 283868,
#  'identifi target': 159650,
#  'target custom': 329825,
#  'custom analys': 82716,
#  'analys busi': 20194,
#  'busi need': 47570,
#  'need make': 218840,
#  'make appropri': 198781,
#  'appropri recommend': 27359,
#  'recommend propos': 272768,
#  'propos servic': 262280,
#  'servic meet': 300615,
#  'meet logist': 206822,
#  'logist need': 195501,
#  'need work': 219119,
#  'work extern': 365156,
#  'custom intern': 83079,
#  'intern depart': 173586,
#  'depart establish': 92222,
#  'establish end': 119077,
#  'end end': 111802,
#  'end solut': 111948,
#  'solut custom': 309976,
#  'custom respons': 83296,
#  'respons price': 284075,
#  'price quotat': 252996,
#  'quotat submiss': 268581,
#  'submiss negoti': 322615,
#  'negoti custom': 219172,
#  'custom ownership': 83194,
#  'ownership propos': 233864,
#  'propos plan': 262233,
#  'plan implement': 243820,
#  'implement respons': 161674,
#  'respons period': 284051,
#  'period busi': 240422,
#  'busi review': 47736,
#  'review includ': 286167,
#  'includ payment': 163787,
#  'payment collect': 238187,
#  'collect custom': 63030,
#  'custom exist': 82968,
#  'exist busi': 123925,
#  'busi constantli': 47168,
#  'constantli explor': 72604,
#  'explor new': 127842,
#  'new area': 220156,
#  'area opportun': 28828,
#  'opportun maintain': 228489,
#  'maintain strong': 198172,
#  'strong custom': 321082,
#  'custom relationship': 83287,
#  'relationship collat': 277031,
#  'collat analys': 62625,
#  'analys market': 20333,
#  'market trend': 203539,
#  'trend competitor': 345260,
#  'competitor activ': 67435,
#  'activ market': 11113,
#  'market busi': 202829,
#  'busi intellig': 47447,
#  'intellig interact': 172075,
#  'interact custom': 172465,
#  ...}

# %%
#Functions imported from preprocessing data
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
stop_words = set(stopwords.words('english'))
def rm_stopwords(tokens):
    return [i for i in tokens if i not in stop_words and i]
ps = PorterStemmer()
def stem_words(tokens):
    return [ps.stem(i) for i in tokens]

# %%
import re
#Function removes special characters, set every word to lower case, tokenize, remove stopwords, and stem words
def preprocess_input(input_str):
    input_str = re.sub('[^A-Za-z0-9]+', ' ', input_str)
    input_str = input_str.lower()
    input_str = input_str.split()
    input_str = rm_stopwords(input_str)
    input_str = stem_words(input_str)
    return list(input_str)

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
def generate_recommendations(input_list):
    #Convert to a string first
    input_text = " ".join(input_list)
    #Then preprocess, the preprocessor would return a list
    input_text = preprocess_input(input_text)
    #Transform the input using tfidf_vectorizer
    recommendation_tf_idf = tfidf_vectorizer.transform([str(input_text)])
    #compute cosine similarity scores between input and every job entry
    scores = cosine_similarity(recommendation_tf_idf,tfidf_job)[0]
    #Return the top 10 jobs with highest cosine similarity scores
    ind = np.argpartition(scores,-10)[-10:][::-1]
    return df_combined.iloc[ind,:]

# %%
#Test input
test_input=["Computer Science","Information Technology","software development","project management","design document","Software product specifications","architectural styles"]
generate_recommendations(test_input)
# Out:
#                                                     url  \
# 4491  https://sg.jobsdb.com/job/Software-Architect-1...
# 3340  https://sg.jobsdb.com/job/6723-software-Archit...
# 2112  https://sg.jobsdb.com/job/Software-Architect-6...
# 2454  https://sg.jobsdb.com/job/Software-Architect-d...
# 5152  https://sg.jobsdb.com/job/Software-Architect-3...
# 1216  https://sg.jobsdb.com/job/Software-Engineer-c3...
# 1520  https://sg.jobsdb.com/job/Software-Engineer-43...
# 726   https://www.mycareersfuture.gov.sg/job/informa...
# 1523  https://sg.jobsdb.com/job/.net-Software-Develo...
# 424   https://www.mycareersfuture.gov.sg/job/informa...
#
#                                      job_title  \
# 4491                 7506 - Software Architect
# 3340      6723-Software Architect [Macpherson]
# 2112  Software Architect @ Ubi - 5Days //-3288
# 2454                        Software Architect
# 5152    2697 - Software Architect [Macpherson]
# 1216                         Software Engineer
# 1520                         Software Engineer
# 726                Senior /  Software Engineer
# 1523                   .Net Software Developer
# 424    Software Developer || Singaporeans Only
#
#                                        description_html  \
# 4491  <div class="-desktop-no-padding-top" id="job-d...
# 3340  <div class="-desktop-no-padding-top" id="job-d...
# 2112  <div class="-desktop-no-padding-top" id="job-d...
# 2454  <div class="-desktop-no-padding-top" id="job-d...
# 5152  <div class="-desktop-no-padding-top" id="job-d...
# 1216  <div class="-desktop-no-padding-top" id="job-d...
# 1520  <div class="-desktop-no-padding-top" id="job-d...
# 726   <p><strong>Responsibilities:</strong></p>\n<ul...
# 1523  <div class="-desktop-no-padding-top" id="job-d...
# 424   <p><u><strong>Job Responsibilities</strong></u...
#
#                                             description  \
# 4491  Location: Ubi\nWorking Days: 5 days work week\...
# 3340  If you are interested to apply, kindly WhatsAp...
# 2112  Software Architect\nLocation: Ubi\nWorking Day...
# 2454  To create printer utility to support the use w...
# 5152  Responsibilities:\n\nCollaborate with various ...
# 1216  Azbil Singapore Pte Ltd, was, established sinc...
# 1520  Job Description\n\n\nExecute full software dev...
# 726   Responsibilities:\n\n  Develop, maintain, and ...
# 1523  Responsibilities:\n\nDevelops and designs new ...
# 424   Job Responsibilities\n\n  Be part of the softw...
#
#                   pay_range   job_type  \
# 4491       $4,000 - $6,000   Permanent
# 3340       $5,000 - $6,000   Permanent
# 2112       $4,500 - $6,000   Permanent
# 2454                    NaN        NaN
# 5152       $5,000 - $6,000   Permanent
# 1216       $3,300 - $6,600   Permanent
# 1520                    NaN        NaN
# 726     $4,000   - $6,500    Full Time
# 1523                    NaN  Full time
# 424     $2,800   - $4,300    Full Time
#
#                                                 company  \
# 4491                            The Supreme HR Advisory
# 3340                            The Supreme HR Advisory
# 2112                            The Supreme HR Advisory
# 2454             SATO Global Business Services Pte. Ltd
# 5152                            The Supreme HR Advisory
# 1216                 Azbil Corporation Singapore Branch
# 1520                          SATO Asia Pacific Pte Ltd
# 726   St Engineering Mission Software &Amp; Services...
# 1523                                Talent Trader Group
# 424                    Apba Tg Human Resource Pte. Ltd.
#
#                                                location  \
# 4491                                  Central Singapore
# 3340                                          Singapore
# 2112                                  Central Singapore
# 2454                                            Geylang
# 5152                                          Singapore
# 1216                                     West Singapore
# 1520                                            Geylang
# 726   ST ENGINEERING HUB, 1 ANG MO KIO ELECTRONICS P...
# 1523                                          Singapore
# 424                                                 NaN
#
#                                      description_tokens  \
# 4491  ['locat', 'ubi', 'work', 'day', '5', 'day', 'w...
# 3340  ['interest', 'appli', 'kindli', 'whatsapp', 'u...
# 2112  ['softwar', 'architect', 'locat', 'ubi', 'work...
# 2454  ['creat', 'printer', 'util', 'support', 'use',...
# 5152  ['respons', 'collabor', 'variou', 'stakehold',...
# 1216  ['azbil', 'singapor', 'pte', 'ltd', 'establish...
# 1520  ['job', 'descript', 'execut', 'full', 'softwar...
# 726   ['respons', 'develop', 'maintain', 'enhanc', '...
# 1523  ['respons', 'develop', 'design', 'new', 'softw...
# 424   ['job', 'respons', 'part', 'softwar', 'team', ...
#
#                                        full_info_tokens  duplicated
# 4491  ['7506', 'softwar', 'architect', 'locat', 'ubi...       False
# 3340  ['6723', 'softwar', 'architect', 'macpherson',...       False
# 2112  ['softwar', 'architect', 'ubi', '5day', '3288'...       False
# 2454  ['softwar', 'architect', 'creat', 'printer', '...       False
# 5152  ['2697', 'softwar', 'architect', 'macpherson',...       False
# 1216  ['softwar', 'engin', 'azbil', 'singapor', 'pte...       False
# 1520  ['softwar', 'engin', 'job', 'descript', 'execu...       False
# 726   ['senior', 'softwar', 'engin', 'respons', 'dev...       False
# 1523  ['net', 'softwar', 'develop', 'respons', 'deve...       False
# 424   ['softwar', 'develop', 'singaporean', 'job', '...       False

# %%
#save tf-idf matrix and vectorizer
import pickle
pickle.dump(tfidf_vectorizer,open('tfidf_vectorizer.pkl','wb'))
pickle.dump(tfidf_job,open('tfidf_job.pkl','wb'))
