# %%
import pandas as pd

# %%
#Read Dataset
df_combined = pd.read_csv("../../Datasets/processed_data.csv")

# %%
df_combined.shape
# Out:
# (6243, 12)

# %%
df_combined.isna().sum()
# Out:
# url                      0
# job_title                0
# description_html         0
# description              0
# job_type               459
# company                  0
# location                 0
# description_tokens       0
# full_info_tokens         0
# duplicated               0
# min_pay               3580
# max_pay               3580
# dtype: int64

# %%
#Overview of dataset
df_combined.head()
# Out:
#                                                  url  \
# 0  https://www.mycareersfuture.gov.sg/job/custome...
# 1  https://www.mycareersfuture.gov.sg/job/enginee...
# 2  https://www.mycareersfuture.gov.sg/job/sales/b...
# 3  https://www.mycareersfuture.gov.sg/job/banking...
# 4  https://www.mycareersfuture.gov.sg/job/archite...
#
#                                            job_title  \
# 0                         PRODUCTION CONTROL MANAGER
# 1       Design Engineer ( Mechanical  /  Electrical)
# 2                     Business Development Executive
# 3                            Senior / Data Scientist
# 4  8890-Sales Consultant [ Digital Software| Saas...
#
#                                     description_html  \
# 0  <p><strong>JOB DESCIPTION</strong></p>\n<ul>\n...
# 1  <p><strong>SUMMARY</strong></p>\n<ul>\n  <li>T...
# 2  <p><strong>Job description</strong></p>\n<p>Wh...
# 3  <p>The ideal candidate should have a good unde...
# 4  <p><strong>Sales Consultant (Digital Software)...
#
#                                          description              job_type  \
# 0  JOB DESCIPTION\n\n  planning and organising pr...  Permanent, Full Time
# 1  SUMMARY\n\n  This      position is responsible...             Full Time
# 2  Job description\nWho we are:\nWe are a logisti...  Part Time, Permanent
# 3  The ideal candidate should have a good underst...  Permanent, Full Time
# 4  Sales Consultant (Digital Software)\nLocation:...  Permanent, Full Time
#
#                                              company  \
# 0                              Snl Logistics Pte Ltd
# 1  Jamco Aero Design &Amp; Engineering Private Li...
# 2                             Airpak Express Pte Ltd
# 3                         Singapore Exchange Limited
# 4                  The Supreme Hr Advisory Pte. Ltd.
#
#                                             location  \
# 0                               31 GUL CIRCLE 629569
# 1                                          Singapore
# 2  TECHPLAS INDUSTRIAL BUILDING, 45 CHANGI SOUTH ...
# 3                 SGX CENTRE I, 2 SHENTON WAY 068804
# 4                SHENTON HOUSE, 3 SHENTON WAY 068805
#
#                                   description_tokens  \
# 0  ['job', 'descipt', 'plan', 'organis', 'product...
# 1  ['summari', 'posit', 'respons', 'support', 'pr...
# 2  ['job', 'descript', 'logist', 'servic', 'provi...
# 3  ['ideal', 'candid', 'good', 'understand', 'bus...
# 4  ['sale', 'consult', 'digit', 'softwar', 'locat...
#
#                                     full_info_tokens  duplicated  min_pay  \
# 0  ['product', 'control', 'manag', 'snl', 'logist...       False   2000.0
# 1  ['design', 'engin', 'mechan', 'electr', 'jamco...       False   2500.0
# 2  ['busi', 'develop', 'execut', 'airpak', 'expre...       False   3200.0
# 3  ['senior', 'data', 'scientist', 'singapor', 'e...       False   9000.0
# 4  ['8890', 'sale', 'consult', 'digit', 'softwar'...       False   3000.0
#
#    max_pay
# 0   3400.0
# 1   4500.0
# 2   3500.0
# 3  14000.0
# 4   4500.0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#Set ngram range to 2 to include phrases
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))

# %%
#Fit full_info_tokens onto the tfidf vectorizer
tfidf_job = tfidf_vectorizer.fit_transform(df_combined['full_info_tokens'])

# %%
#Check if tfidf_vectorizer worked correctly
tfidf_vectorizer.vocabulary_
# Out:
# {'product': 258349,
#  'control': 76638,
#  'manag': 201004,
#  'snl': 310443,
#  'logist': 196933,
#  'pte': 265929,
#  'ltd': 198194,
#  'perman': 242372,
#  'full': 142112,
#  'time': 340464,
#  '31': 4082,
#  'gul': 152404,
#  'circl': 58601,
#  '629569': 5636,
#  'job': 180426,
#  'descipt': 94528,
#  'plan': 245340,
#  'organis': 232367,
#  'schedul': 295203,
#  'assess': 31688,
#  'project': 262031,
#  'resourc': 284227,
#  'requir': 281714,
#  'estim': 120747,
#  'negoti': 220803,
#  'agre': 16727,
#  'budget': 46787,
#  'timelin': 341362,
#  'client': 60170,
#  'ensur': 116287,
#  'health': 154352,
#  'safeti': 292573,
#  'regul': 277083,
#  'met': 209914,
#  'determin': 96868,
#  'qualiti': 268335,
#  'standard': 318505,
#  'overse': 234681,
#  'process': 256971,
#  'select': 299653,
#  'order': 231470,
#  'purchas': 266341,
#  'materi': 205801,
#  'repair': 280108,
#  'routin': 291360,
#  'mainten': 199769,
#  'equip': 118913,
#  'liais': 192379,
#  'buyer': 49111,
#  'supervis': 326214,
#  'day': 88329,
#  'work': 366818,
#  'junior': 182258,
#  'staff': 317435,
#  'worker': 368292,
#  'factori': 131233,
#  'environ': 117916,
#  'relev': 278875,
#  'train': 345142,
#  'session': 302668,
#  'goal': 147724,
#  'within': 365888,
#  'approv': 28352,
#  'min': 212140,
#  'diploma': 100339,
#  'year': 370936,
#  'supervisori': 326473,
#  'experi': 126143,
#  'similar': 306009,
#  'industri': 167150,
#  'manufactu': 203648,
#  'pc': 240231,
#  'liter': 195444,
#  'well': 363907,
#  'organ': 231813,
#  'team': 332723,
#  'player': 247013,
#  'will': 365374,
#  'west': 364628,
#  'area': 29446,
#  'compani': 67193,
#  'transport': 346840,
#  'pioneer': 244524,
#  'choa': 58233,
#  'chu': 58385,
#  'kang': 182739,
#  'mrt': 217392,
#  'extens': 129812,
#  'knowledg': 184240,
#  'product control': 258591,
#  'control manag': 76924,
#  'manag snl': 202528,
#  'snl logist': 310444,
#  'logist pte': 197023,
#  'pte ltd': 265932,
#  'ltd perman': 198302,
#  'perman full': 242433,
#  'full time': 142237,
#  'time 31': 340495,
#  '31 gul': 4093,
#  'gul circl': 152407,
#  'circl 629569': 58603,
#  '629569 job': 5637,
#  'job descipt': 180541,
#  'descipt plan': 94529,
#  'plan organis': 245733,
#  'organis product': 232589,
#  'product schedul': 259316,
#  'schedul assess': 295226,
#  'assess project': 31911,
#  'project resourc': 262735,
#  'resourc requir': 284486,
#  'requir estim': 282066,
#  'estim negoti': 120805,
#  'negoti agre': 220806,
#  'agre budget': 16737,
#  'budget timelin': 46944,
#  'timelin client': 341376,
#  'client ensur': 60433,
#  'ensur health': 116581,
#  'health safeti': 154503,
#  'safeti regul': 292723,
#  'regul met': 277236,
#  'met determin': 209939,
#  'determin qualiti': 96980,
#  'qualiti control': 268440,
#  'control standard': 77100,
#  'standard overse': 318782,
#  'overse product': 234781,
#  'product process': 259199,
#  'process select': 257798,
#  'select order': 299745,
#  'order purchas': 231643,
#  'purchas materi': 266380,
#  'materi organis': 205952,
#  'organis repair': 232609,
#  'repair routin': 280155,
#  'routin mainten': 291396,
#  'mainten product': 200003,
#  'product equip': 258730,
#  'equip liais': 119051,
#  'liais buyer': 192396,
#  'buyer supervis': 49131,
#  'supervis manag': 326309,
#  'manag day': 201457,
#  'day day': 88440,
#  'day work': 88679,
#  'work junior': 367518,
#  'junior staff': 182333,
#  'staff product': 317598,
#  'product worker': 259559,
#  'worker factori': 368309,
#  'factori environ': 131249,
#  'environ organis': 118411,
#  'organis relev': 232607,
#  'relev train': 279251,
#  'train session': 345546,
#  'session ensur': 302704,
#  'ensur project': 116769,
#  'project goal': 262407,
#  'goal met': 147910,
#  'met within': 210006,
#  'within approv': 365924,
#  'approv budget': 28371,
#  'budget requir': 46916,
#  'requir min': 282332,
#  'min diploma': 212153,
#  'diploma manag': 100400,
#  'manag min': 202044,
#  'min year': 212175,
#  'year supervisori': 371374,
#  'supervisori experi': 326480,
#  'experi year': 127830,
#  'year experi': 371115,
#  'experi similar': 127543,
#  'similar industri': 306061,
#  'industri manufactu': 167549,
#  'manufactu pc': 203649,
#  'pc liter': 240247,
#  'liter well': 195460,
#  'well organ': 364347,
#  'organ team': 232306,
#  'team player': 333712,
#  'player will': 247261,
#  'will work': 365447,
#  'work west': 368191,
#  'west area': 364634,
#  'area compani': 29539,
#  'compani transport': 67946,
#  'transport pioneer': 346905,
#  'pioneer choa': 244535,
#  'choa chu': 58234,
#  'chu kang': 58389,
#  'kang mrt': 182744,
#  'mrt extens': 217404,
#  'extens knowledg': 129864,
#  'knowledg safeti': 185039,
#  'safeti process': 292711,
#  'design': 95062,
#  'engin': 114008,
#  'mechan': 207675,
#  'electr': 110370,
#  'jamco': 179413,
#  'aero': 15615,
#  'amp': 20738,
#  'privat': 255857,
#  'limit': 194118,
#  'singapor': 306579,
#  'summari': 325843,
#  'posit': 249417,
#  'respons': 284836,
#  'support': 326756,
#  'senior': 300318,
#  'level': 191469,
#  'research': 282901,
#  'substanti': 324804,
#  'payload': 239813,
#  'system': 329095,
#  'structur': 323357,
#  'depart': 93263,
#  'util': 355582,
#  'establish': 120338,
#  'model': 214178,
#  'draft': 104816,
#  'develop': 97081,
#  'aircraft': 17718,
#  'packag': 235880,
#  'base': 39192,
#  'custom': 83880,
#  'retrofit': 286902,
#  'applic': 26671,
#  'essenti': 120172,
#  'duti': 106424,
#  'responsibilit': 285727,
#  'includ': 164343,
#  'follow': 138154,
#  'assign': 32268,
#  'perform': 241245,
#  'accord': 8866,
#  'lead': 188305,
#  'task': 331949,
#  'basic': 40122,
#  'instal': 171662,
#  'detail': 96281,
#  'assembl': 31616,
#  'specif': 315123,
#  'direct': 100449,
#  'experienc': 127839,
#  'maintain': 199241,
#  'modifi': 215239,
#  'defin': 90601,
#  'use': 354057,
#  'tool': 342460,
#  'particip': 237554,
#  'document': 103516,
#  'implement': 162430,
#  'obtain': 225461,
#  'interpret': 175855,
#  'analyz': 23897,
#  'oem': 225781,
#  'airplan': 17814,
#  'draw': 104907,
#  'troubleshoot': 347955,
#  'problem': 256207,
#  'activ': 11521,
#  'initi': 169553,
#  'coordin': 77645,
#  'necessari': 219902,
#  'intern': 174700,
#  'per': 241066,
#  'regulatori': 277518,
#  'agenc': 16044,
#  'domest': 104358,
#  'travel': 346945,
#  'may': 206777,
#  'qualif': 267916,
#  'success': 324933,
#  'individu': 166742,
#  'must': 218501,
#  'abl': 7508,
#  'list': 195227,
#  'repres': 281155,
#  'skill': 308565,
#  'abil': 6984,
#  'qualifi': 268203,
#  'degre': 91011,
#  'aerospac': 15625,
#  'relat': 277805,
#  'field': 133689,
#  'aviat': 36502,
#  'practic': 251480,
#  'scienc': 295749,
#  'technolog': 335513,
#  'appli': 26192,
#  'principl': 254954,
#  'techniqu': 335150,
#  'procedur': 256692,
#  'variou': 357344,
#  'good': 148155,
#  'servic': 301655,
#  'read': 272779,
#  'understand': 350076,
#  'comput': 70397,
#  'aid': 17417,
#  'cad': 49437,
#  'involv': 177360,
#  'precis': 252136,
#  'technic': 334675,
#  'administr': 13692,
#  'accept': 8342,
#  'role': 290184,
#  'account': 9094,
#  'solv': 312672,
#  'identifi': 160597,
#  'complex': 69083,
#  'review': 287289,
#  'inform': 168268,
#  'evalu': 121872,
#  'option': 231097,
#  'solut': 311621,
#  'critic': 81933,
#  'think': 339040,
#  'logic': 196794,
#  'reason': 273276,
#  'strength': 322582,
#  'weak': 362927,
#  'altern': 19804,
#  'conclus': 71365,
#  'approach': 27760,
#  'scientif': 296279,
#  'rule': 291679,
#  'method': 210141,
#  'mathemat': 206095,
#  'concept': 70797,
#  'measur': 207391,
#  'fraction': 140520,
#  'percentag': 241179,
#  'ratio': 272288,
#  'trigonometri': 347852,
#  'imaginari': 161664,
#  'number': 224313,
#  'proport': 263645,
#  'formula': 139854,
#  'embed': 111166,
#  'linkag': 194948,
#  'amongst': 20671,
#  'cell': 54106,
#  'spreadsheet': 316223,
#  'program': 260723,
#  'orient': 232800,
#  'demonstr': 92901,
#  'concern': 71215,
#  'take': 330864,
#  'action': 11234,
#  'meet': 208299,
#  'high': 155718,
#  'extern': 129932,
#  'display': 102103,
#  'courtesi': 79825,
#  'sensit': 300698,
#  'difficult': 99682,
#  'situat': 308308,
#  'commit': 65905,
#  'respond': 284744,
#  'promptli': 263311,
#  'need': 220146,
#  'solicit': 311483,
#  'feedback': 133131,
#  'improv': 163358,
#  'commun': 66440,
#  'give': 146457,
#  'attent': 34110,
#  'peopl': 240647,
#  'say': 294246,
#  'point': 248133,
#  'made': 198904,
#  'ask': 31269,
#  'question': 269637,
#  'appropri': 28087,
#  'interrupt': 175983,
#  'inappropri': 164046,
#  'effect': 108798,
#  'write': 369871,
#  'audienc': 34555,
#  'talk': 331475,
#  'other': 233350,
#  'convey': 77426,
#  'oral': 231348,
#  'written': 370160,
#  'languag': 186726,
#  'gener': 145102,
#  'busi': 48029,
#  'period': 242091,
#  'data': 85976,
#  'government': 149085,
#  'formal': 139470,
#  'correspond': 78743,
#  'judgment': 182114,
#  'decis': 89692,
#  'make': 200285,
#  'consid': 73101,
#  'rel': 277783,
#  'cost': 78836,
#  'benefit': 41674,
#  'potenti': 250643,
#  'choos': 58306,
#  'one': 227365,
#  'multitask': 218298,
#  'independ': 166140,
#  'attitud': 34172,
#  'continu': 75586,
#  'profession': 259657,
#  'design engin': 95344,
#  'engin mechan': 114781,
#  'mechan electr': 207711,
#  'electr jamco': 110413,
#  'jamco aero': 179414,
#  'aero design': 15616,
#  'design amp': 95104,
#  'amp engin': 20763,
#  'engin privat': 114969,
#  'privat limit': 255885,
#  'limit full': 194242,
#  'time singapor': 341168,
#  'singapor summari': 307661,
#  'summari posit': 325924,
#  'posit respons': 249812,
#  'respons support': 285625,
#  'support project': 327600,
#  'project team': 262858,
#  'team senior': 333895,
#  'senior level': 300443,
#  'level engin': 191630,
#  'engin research': 115071,
#  'research design': 283086,
#  'design substanti': 95808,
#  'substanti electr': 324814,
#  'electr mechan': 110420,
#  'mechan payload': 207755,
#  'payload system': 239815,
#  'system structur': 330064,
#  'structur design': 323442,
#  'design within': 95889,
#  'within engin': 366077,
#  'engin depart': 114359,
#  'depart util': 93626,
#  'util establish': 355636,
#  'establish process': 120555,
#  'process model': 257552,
#  'model draft': 214427,
#  'draft standard': 104876,
#  'standard design': 318625,
#  'engin support': 115232,
#  'support design': 327064,
#  'design develop': 95299,
#  'develop aircraft': 97144,
#  'aircraft engin': 17722,
#  'engin packag': 114910,
#  'packag base': 235902,
#  'base custom': 39345,
#  'custom requir': 84508,
#  'requir product': 282472,
#  'product retrofit': 259285,
#  'retrofit applic': 286903,
#  'applic product': 27317,
#  'product develop': 258664,
#  'develop essenti': 97550,
#  'essenti duti': 120207,
#  'duti responsibilit': 106545,
#  'responsibilit includ': 285731,
#  'includ follow': 164766,
#  'follow duti': 138303,
#  'duti assign': 106433,
#  'assign perform': 32430,
#  'perform design': 241463,
#  'design assign': 95134,
#  'assign accord': 32275,
#  'accord establish': 8922,
#  'establish design': 120427,
#  'design standard': 95789,
#  'standard supervis': 318894,
#  'supervis lead': 326302,
#  'lead senior': 188911,
#  'senior engin': 300378,
#  'engin assign': 114145,
#  'assign design': 32339,
#  'design task': 95822,
#  'task includ': 332100,
#  'includ limit': 164940,
#  'limit basic': 194156,
#  'basic aircraft': 40151,
#  'aircraft design': 17721,
#  'design electr': 95330,
#  'mechan structur': 207785,
#  'structur payload': 323562,
#  'system instal': 329617,
#  'instal detail': 171692,
#  'detail assembl': 96312,
#  'assembl system': 31665,
#  'system specif': 330044,
#  'specif work': 315540,
#  'work direct': 367189,
#  'direct experienc': 100558,
#  'experienc engin': 127913,
#  'engin maintain': 114756,
#  'maintain modifi': 199528,
#  'modifi basic': 215242,
#  'basic electr': 40199,
#  'system base': 329201,
#  'base defin': 39355,
#  'defin requir': 90811,
#  'requir use': 282751,
#  'use approv': 354119,
#  'approv process': 28455,
#  'process tool': 257917,
#  'tool particip': 342954,
#  'particip project': 237804,
#  'team support': 333999,
#  'support develop': 327070,
#  'develop design': 97462,
#  'design support': 95812,
#  'support document': 327088,
#  'document design': 103667,
#  'design implement': 95459,
#  'implement obtain': 162861,
#  'obtain interpret': 225494,
#  'interpret analyz': 175862,
#  'analyz oem': 24054,
#  'oem airplan': 225783,
#  'airplan instal': 17815,
#  'instal draw': 171694,
#  'draw use': 104988,
#  'tool troubleshoot': 343180,
#  'troubleshoot basic': 347970,
#  'basic mechan': 40246,
#  'system problem': 329876,
#  'problem activ': 256221,
#  'activ support': 12075,
#  'support engin': 327129,
#  'depart project': 93543,
#  'team goal': 333349,
#  'goal initi': 147877,
#  'initi coordin': 169664,
#  'coordin depart': 77732,
#  'depart necessari': 93502,
#  'necessari util': 220119,
#  'util intern': 355660,
#  'intern draw': 174909,
#  'draw document': 104933,
#  'document standard': 103974,
#  'standard per': 318791,
#  'per custom': 241087,
#  'custom regulatori': 84500,
#  'regulatori agenc': 277526,
#  'agenc requir': 16216,
#  'requir domest': 282014,
#  'domest intern': 104368,
#  'intern travel': 175382,
#  'travel may': 347020,
#  'may requir': 206942,
#  'requir qualif': 282494,
#  'qualif perform': 268103,
#  'perform job': 241658,
#  'job success': 180843,
#  'success individu': 325121,
#  'individu must': 166951,
#  'must abl': 218506,
#  'abl perform': 7724,
#  'perform essenti': 241519,
#  'duti direct': 106460,
#  'engin establish': 114446,
#  'establish depart': 120426,
#  'depart standard': 93591,
#  'standard process': 318814,
#  'process requir': 257759,
#  'requir list': 282287,
#  'list repres': 195357,
#  'repres knowledg': 281229,
#  'knowledg skill': 185079,
#  'skill abil': 308573,
#  'abil requir': 7393,
#  'requir requir': 282544,
#  'requir qualifi': 282495,
#  'qualifi degre': 268220,
#  'degre mechan': 91204,
#  'electr engin': 110395,
#  'engin aerospac': 114075,
#  'aerospac engin': 15635,
#  'engin relat': 115060,
#  'relat engin': 277989,
#  'engin field': 114493,
#  'field year': 134046,
#  'experi engin': 126641,
#  'engin aviat': 114163,
#  'aviat relat': 36524,
#  'relat field': 278016,
#  'field knowledg': 133864,
#  'knowledg engin': 184535,
#  'engin knowledg': 114706,
#  'knowledg practic': 184939,
#  'practic applic': 251507,
#  'applic engin': 26958,
#  'engin scienc': 115106,
#  'scienc technolog': 296212,
#  'technolog includ': 335993,
#  'includ appli': 164410,
#  'appli principl': 26520,
#  'principl techniqu': 255131,
#  'techniqu procedur': 335400,
#  'procedur equip': 256773,
#  'equip design': 118984,
#  'design product': 95664,
#  'product variou': 259515,
#  'variou system': 357702,
#  'system good': 329541,
#  'good servic': 148500,
#  'servic design': 301919,
#  'design abl': 95069,
#  'abl read': 7755,
#  'read understand': 272848,
#  'understand comput': 350246,
#  'comput aid': 70404,
#  'aid design': 17430,
#  'design cad': 95172,
#  'cad design': 49440,
#  'design draw': 95318,
#  'draw specif': 104976,
#  'specif knowledg': 315338,
#  'knowledg design': 184480,
#  'design techniqu': 95828,
#  'techniqu tool': 335473,
#  'tool principl': 342992,
#  'principl involv': 255051,
#  'involv product': 177614,
#  'product precis': 259179,
#  'precis technic': 252183,
#  'technic plan': 334956,
#  'plan draw': 245534,
#  'draw model': 104955,
#  'model administr': 214199,
#  'administr abl': 13698,
#  'abl work': 7841,
#  'work team': 368082,
#  'team environ': 333211,
#  'environ accept': 117926,
#  'accept requir': 8420,
#  'requir role': 282563,
#  'role respons': 290795,
#  'respons account': 284848,
#  'account skill': 9448,
#  'skill problem': 309234,
#  'problem solv': 256602,
#  'solv identifi': 312803,
#  'identifi complex': 160668,
#  'complex problem': 69289,
#  'problem review': 256572,
#  'review relat': 287683,
#  'relat inform': 278069,
#  'inform develop': 168422,
#  'develop evalu': 97555,
#  'evalu option': 122083,
#  'option implement': 231153,
#  'implement solut': 163023,
#  'solut critic': 311853,
#  'critic think': 82128,
#  'think use': 339280,
#  'use logic': 354531,
#  'logic reason': 196896,
#  'reason identifi': 273311,
#  'identifi strength': 160955,
#  'strength weak': 322626,
#  'weak altern': 362930,
#  'altern solut': 19866,
#  'solut conclus': 311820,
#  'conclus approach': 71369,
#  'approach problem': 27987,
#  'problem use': 256662,
#  'use scientif': 354771,
#  'scientif rule': 296356,
#  'rule method': 291745,
#  'method solv': 210383,
#  'solv problem': 312885,
#  'problem requir': 256563,
#  'requir mathemat': 282313,
#  'mathemat abil': 206096,
#  'abil work': 7504,
#  'work mathemat': 367593,
#  'mathemat concept': 206121,
#  'concept measur': 70977,
#  'measur appli': 207412,
#  'appli concept': 26283,
#  'concept fraction': 70917,
#  'fraction percentag': 140524,
#  'percentag ratio': 241182,
#  'ratio trigonometri': 272302,
#  'trigonometri imaginari': 347853,
#  'imaginari number': 161665,
#  'number proport': 224459,
#  'proport abil': 263646,
#  'abil use': 7489,
#  'use variou': 354933,
#  'variou formula': 357498,
#  'formula embed': 139862,
#  'embed linkag': 111204,
#  'linkag amongst': 194951,
#  'amongst cell': 20673,
#  'cell spreadsheet': 54136,
#  'spreadsheet program': 316243,
#  'program custom': 260899,
#  'custom orient': 84405,
#  'orient must': 232961,
#  'must demonstr': 218574,
#  'demonstr concern': 92946,
#  'concern take': 71272,
#  'take action': 330873,
#  'action meet': 11393,
#  'meet requir': 208564,
#  'requir high': 282180,
#  'high standard': 155864,
#  'standard qualiti': 318830,
#  'qualiti intern': 268582,
#  'intern extern': 174964,
#  'extern custom': 129992,
#  'custom must': 84374,
#  'must display': 218579,
#  'display courtesi': 102110,
#  'courtesi sensit': 79826,
#  'sensit manag': 300736,
#  'manag difficult': 201503,
#  'difficult situat': 99703,
#  'situat meet': 308368,
#  'meet commit': 208352,
#  'commit respond': 66083,
#  'respond promptli': 284808,
#  'promptli custom': 263316,
#  'custom need': 84377,
#  'need solicit': 220688,
#  'solicit custom': 311485,
#  'custom feedback': 84201,
#  'feedback improv': 133233,
#  'improv servic': 163882,
#  'servic commun': 301847,
#  'commun give': 66735,
#  'give full': 146501,
#  'full attent': 142120,
#  'attent peopl': 34147,
#  'peopl say': 240953,
#  'say take': 294255,
#  'take time': 331097,
#  'time understand': 341267,
#  'understand point': 350707,
#  'point made': 248259,
#  'made ask': 198908,
#  'ask question': 31308,
#  'question appropri': 269645,
#  'appropri interrupt': 28216,
#  'interrupt inappropri': 175985,
#  'inappropri time': 164049,
#  'time commun': 340637,
#  'commun effect': 66646,
#  'effect write': 109286,
#  'write appropri': 369892,
#  'appropri need': 28254,
#  'need audienc': 220213,
#  'audienc talk': 34698,
#  'talk other': 331491,
#  'other convey': 233394,
#  'convey inform': 77441,
#  'inform effect': 168448,
#  'effect good': 108994,
#  'good oral': 148417,
#  'oral written': 231378,
#  'written commun': 370183,
#  'commun skill': 67036,
#  'skill languag': 309054,
#  'languag abil': 186728,
#  'abil read': 7377,
#  'read analyz': 272785,
#  'analyz interpret': 24014,
#  'interpret gener': 175902,
#  'gener busi': 145161,
#  'busi period': 48675,
#  'period procedur': 242206,
#  'procedur draw': 256763,
#  'draw technic': 104980,
#  'technic data': 334768,
#  'data engin': 86350,
#  'engin document': 114389,
#  'document government': 103735,
#  'government regul': 149087,
#  'regul abil': 277086,
#  'abil write': 7505,
#  'write engin': 369965,
#  'document formal': 103722,
#  'formal busi': 139474,
#  'busi correspond': 48242,
#  'correspond judgment': 78761,
#  'judgment decis': 182126,
#  'decis make': 89868,
#  'make consid': 200377,
#  'consid rel': 73222,
#  'rel cost': 277786,
#  'cost benefit': 78855,
#  'benefit potenti': 41869,
#  'potenti action': 250648,
#  'action choos': 11267,
#  'choos appropri': 58311,
#  'appropri one': 28257,
#  'one time': 227774,
#  'time manag': 340920,
#  'manag manag': 201988,
#  'manag one': 202136,
#  'time abl': 340521,
#  'abl multitask': 7710,
#  'multitask work': 218343,
#  'work independ': 367455,
#  'independ attitud': 166172,
#  'attitud demonstr': 34209,
#  'demonstr continu': 92950,
#  'continu skill': 75771,
#  'skill improv': 308996,
#  'improv profession': 163810,
#  'profession posit': 259909,
#  'posit attitud': 249456,
#  'attitud requir': 34292,
#  'execut': 124437,
#  'airpak': 17812,
#  'express': 129637,
#  'part': 236893,
#  'techpla': 336617,
#  'build': 47042,
#  '45': 4728,
#  'changi': 56725,
#  'south': 313929,
#  'avenu': 36439,
#  '486133': 4825,
#  'descript': 94574,
#  'provid': 264760,
#  'solid': 311496,
#  'infrastructur': 169012,
#  'foundat': 140251,
#  'built': 47807,
#  'decad': 89593,
#  'constantli': 73705,
#  'move': 217085,
#  'ahead': 16942,
#  'trend': 347333,
#  'remain': 279541,
#  'headquart': 154288,
#  'proudli': 264639,
#  'singaporean': 307795,
#  'outreach': 234141,
#  'fresh': 141454,
#  'grad': 149349,
#  'keen': 182887,
#  'interest': 174026,
#  'welcom': 363783,
#  'learner': 190486,
#  'knack': 184003,
#  'flexibl': 136694,
#  'fast': 132177,
#  'pace': 235606,
#  'energet': 113308,
#  'competit': 68407,
#  'salari': 292848,
#  'growth': 151270,
#  'segment': 299421,
#  'target': 331681,
#  'analys': 20878,
#  'recommend': 273961,
#  'propos': 263648,
#  'end': 112925,
#  'price': 254417,
#  'quotat': 270122,
#  'submiss': 324467,
#  'ownership': 235359,
#  'payment': 239816,
#  'collect': 64144,
#  'exist': 125256,
#  'explor': 129044,
#  'new': 221783,
#  'opportun': 229738,
#  'strong': 322879,
#  'relationship': 278399,
#  'collat': 63807,
#  'market': 204350,
#  'competitor': 68568,
#  'intellig': 173162,
#  'interact': 173689,
#  'partner': 238077,
#  'entiti': 117524,
#  'long': 197142,
#  'term': 337254,
#  'clientel': 61012,
#  'leverag': 192045,
#  'expertis': 128484,
#  'suppli': 326511,
#  'chain': 55514,
#  'candid': 50362,
#  'possess': 249947,
#  'least': 190647,
#  'advanc': 14305,
#  'higher': 155901,
#  'graduat': 149442,
#  'english': 115408,
#  'busi develop': 48288,
#  'develop execut': 97566,
#  'execut airpak': 124475,
#  'airpak express': 17813,
#  'express pte': 129698,
#  'ltd part': 198300,
#  'part time': 237320,
#  'time perman': 341016,
#  'perman techpla': 242506,
#  'techpla industri': 336618,
#  'industri build': 167257,
#  'build 45': 47054,
#  '45 changi': 4731,
#  'changi south': 56773,
#  'south avenu': 313936,
#  'avenu 486133': 36453,
#  '486133 job': 4826,
#  'job descript': 180542,
#  'descript logist': 94790,
#  'logist servic': 197035,
#  'servic provid': 302333,
#  'provid solid': 265469,
#  'solid infrastructur': 311543,
#  'infrastructur foundat': 169152,
#  'foundat built': 140267,
#  'built decad': 47832,
#  'decad experi': 89599,
#  'experi constantli': 126462,
#  'constantli move': 73744,
#  'move ahead': 217089,
#  'ahead logist': 16959,
#  'logist trend': 197056,
#  'trend remain': 347605,
#  'remain relev': 279587,
#  'relev headquart': 279031,
#  'headquart singapor': 154325,
#  'singapor proudli': 307474,
#  'proudli singaporean': 264644,
#  'singaporean intern': 307815,
#  'intern outreach': 175165,
#  'outreach fresh': 234148,
#  'fresh grad': 141468,
#  'grad keen': 149356,
#  'keen interest': 182927,
#  'interest logist': 174224,
#  'logist industri': 196986,
#  'industri welcom': 167843,
#  'welcom experi': 363815,
#  'experi requir': 127430,
#  'requir train': 282721,
#  'train provid': 345487,
#  'provid keen': 265195,
#  'keen learner': 182933,
#  'learner knack': 190539,
#  'knack appli': 184005,
#  'appli knowledg': 26432,
#  'knowledg flexibl': 184586,
#  'flexibl fast': 136754,
#  'fast pace': 132238,
#  'pace energet': 235638,
#  'energet environ': 113327,
#  'environ competit': 118063,
#  'competit salari': 68533,
#  'salari packag': 292964,
#  'packag growth': 235967,
#  'growth segment': 151591,
#  'segment industri': 299510,
#  'industri respons': 167702,
#  'respons identifi': 285256,
#  'identifi target': 160967,
#  'target custom': 331734,
#  'custom analys': 83934,
#  'analys busi': 20911,
#  'busi need': 48624,
#  'need make': 220505,
#  'make appropri': 200314,
#  'appropri recommend': 28287,
#  'recommend propos': 274184,
#  'propos servic': 263843,
#  'servic meet': 302188,
#  'meet logist': 208484,
#  'logist need': 197002,
#  'need work': 220777,
#  'work extern': 367294,
#  'custom intern': 84296,
#  'intern depart': 174888,
#  'depart establish': 93392,
#  'establish end': 120438,
#  'end end': 113016,
#  'end solut': 113162,
#  'solut custom': 311858,
#  'custom respons': 84512,
#  'respons price': 285463,
#  'price quotat': 254603,
#  'quotat submiss': 270144,
#  ...}

# %%
#Functions imported from preprocessing data
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
stop_words = set(stopwords.words('english'))
def rm_stopwords(tokens):
    return [i for i in tokens if i not in stop_words and i]
ps = PorterStemmer()
def stem_words(tokens):
    return [ps.stem(i) for i in tokens]

# %%
import re
#Function removes special characters, set every word to lower case, tokenize, remove stopwords, and stem words
def preprocess_input(input_str):
    input_str = re.sub('[^A-Za-z0-9]+', ' ', input_str)
    input_str = input_str.lower()
    input_str = input_str.split()
    input_str = rm_stopwords(input_str)
    input_str = stem_words(input_str)
    return list(input_str)

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
def generate_recommendations(input_list):
    #Convert to a string first
    input_text = " ".join(input_list)
    #Then preprocess, the preprocessor would return a list
    input_text = preprocess_input(input_text)
    #Transform the input using tfidf_vectorizer
    recommendation_tf_idf = tfidf_vectorizer.transform([str(input_text)])
    #compute cosine similarity scores between input and every job entry
    scores = cosine_similarity(recommendation_tf_idf,tfidf_job)[0]
    #Return the top 10 jobs with highest cosine similarity scores
    ind = np.argpartition(scores,-10)[-10:][::-1]
    return df_combined.iloc[ind,:]

# %%
#Test input
test_input=["python","R","sql","git","flask","docker"]
generate_recommendations(test_input)
# Out:
#                                                     url  \
# 4947  https://sg.jobsdb.com/job/Data-Engineer-63fbe1...
# 4728  https://sg.jobsdb.com/job/Software-Engineer-45...
# 5119  https://sg.jobsdb.com/job/Backend-Engineer-d00...
# 799   https://www.mycareersfuture.gov.sg/job/informa...
# 2707  https://sg.jobsdb.com/job/Software-Engineer-35...
# 1726  https://sg.jobsdb.com/job/Sql-Data-Engineer-c0...
# 1976  https://sg.jobsdb.com/job/Senior-Software-Engi...
# 4227  https://sg.jobsdb.com/job/Developer-9af02f230f...
# 5817  https://sg.jobsdb.com/job/Software-Engineer-c0...
# 4866  https://sg.jobsdb.com/job/Research-Engineer-83...
#
#                                               job_title  \
# 4947                                      Data Engineer
# 4728                 Software Engineer (Backend/Python)
# 5119                                   Backend Engineer
# 799                        Data Engineer - Python / SQL
# 2707                                  Software Engineer
# 1726                         Python / sql data engineer
# 1976                           Senior Software Engineer
# 4227                     Full Stack Developer (ART-652)
# 5817                                  Software Engineer
# 4866  Research Engineer - (Natural Language Processing)
#
#                                        description_html  \
# 4947  <div class="-desktop-no-padding-top" id="job-d...
# 4728  <div class="-desktop-no-padding-top" id="job-d...
# 5119  <div class="-desktop-no-padding-top" id="job-d...
# 799   <p><strong>[Order Number: 2208-62898]</strong>...
# 2707  <div class="-desktop-no-padding-top" id="job-d...
# 1726  <div class="-desktop-no-padding-top" id="job-d...
# 1976  <div class="-desktop-no-padding-top" id="job-d...
# 4227  <div class="-desktop-no-padding-top" id="job-d...
# 5817  <div class="-desktop-no-padding-top" id="job-d...
# 4866  <div class="-desktop-no-padding-top" id="job-d...
#
#                                             description   job_type  \
# 4947  Key Skills: Python, SQL, Unix, AWS\nObjectives...  Permanent
# 4728  Salary\n$6,000 - $10,000 a month\nJob Type\nFu...  Full time
# 5119  Job Description\nBe a part of the robotics rev...  Permanent
# 799   [Order Number: 2208-62898]\n\nResponsibilities...  Full Time
# 2707  Job Description\n\nEngage in feasibility analy...  Full time
# 1726  \nPython/SQL Data Engineer Avensys is a repute...        NaN
# 1976  Job Description\n\nResearch solutions for tech...  Full time
# 4227  \nDevelop and support GIC's Corporate Services...  Permanent
# 5817  The Software Engineer position is based in Sin...  Full time
# 4866  \nJob Responsibilities\nDevelopment and evalua...  Full time
#
#                                        company   location  \
# 4947               UNISON CONSULTING PTE. LTD.     Changi
# 4728     Astek Singapore Innovation Technology  Singapore
# 5119                           KABAM PTE. LTD.  Serangoon
# 799   Good Job Creations (Singapore) Pte. Ltd.  Singapore
# 2707                         Temp-Team Pte Ltd  Singapore
# 1726                        Avensys Consulting  Singapore
# 1976                                    Elitez    Kallang
# 4227                  FPT Asia Pacific Pte Ltd  Singapore
# 5817                              Kiteworks ®      Bedok
# 4866          Nanyang Technological University  Singapore
#
#                                      description_tokens  \
# 4947  ['key', 'skill', 'python', 'sql', 'unix', 'aw'...
# 4728  ['salari', '6', '000', '10', '000', 'month', '...
# 5119  ['job', 'descript', 'part', 'robot', 'revolut'...
# 799   ['order', 'number', '2208', '62898', 'respons'...
# 2707  ['job', 'descript', 'engag', 'feasibl', 'analy...
# 1726  ['python', 'sql', 'data', 'engin', 'avensi', '...
# 1976  ['job', 'descript', 'research', 'solut', 'tech...
# 4227  ['develop', 'support', 'gic', 'corpor', 'servi...
# 5817  ['softwar', 'engin', 'posit', 'base', 'singapo...
# 4866  ['job', 'respons', 'develop', 'evalu', 'natur'...
#
#                                        full_info_tokens  duplicated  min_pay  \
# 4947  ['data', 'engin', 'unison', 'consult', 'pte', ...       False   4000.0
# 4728  ['softwar', 'engin', 'backend', 'python', 'ast...       False   6000.0
# 5119  ['backend', 'engin', 'kabam', 'pte', 'ltd', 'p...       False   3500.0
# 799   ['data', 'engin', 'python', 'sql', 'good', 'jo...       False   5000.0
# 2707  ['softwar', 'engin', 'temp', 'team', 'pte', 'l...       False   4500.0
# 1726  ['python', 'sql', 'data', 'engin', 'avensi', '...       False      NaN
# 1976  ['senior', 'softwar', 'engin', 'elitez', 'full...       False   7000.0
# 4227  ['full', 'stack', 'develop', 'art', '652', 'fp...       False   6000.0
# 5817  ['softwar', 'engin', 'kitework', 'full', 'time...       False      NaN
# 4866  ['research', 'engin', 'natur', 'languag', 'pro...       False      NaN
#
#       max_pay
# 4947   5000.0
# 4728  10000.0
# 5119   4500.0
# 799    8000.0
# 2707   6000.0
# 1726      NaN
# 1976  11000.0
# 4227   7500.0
# 5817      NaN
# 4866      NaN

# %%
#save tf-idf matrix and vectorizer
import pickle
pickle.dump(tfidf_vectorizer,open('tfidf_vectorizer.pkl','wb'))
pickle.dump(tfidf_job,open('tfidf_job.pkl','wb'))
