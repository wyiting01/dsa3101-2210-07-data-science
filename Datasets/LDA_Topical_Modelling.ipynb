# %% [markdown]
# ## Introduction
# We wanted to further explore whether clustering methods can be used to provide recommendations. Ideally, users input their skills and the recommender system would output the jobs from the cluster closest to their input. The clustering method we will explore here is a Latent Dirichlet Allocation model, which would cluster the jobs based on their descriptions and provide the key terms used to identify each cluster

# %%
#Import Packages
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pandas as pd
import numpy as np

# %%
#Read data on jobs
df = pd.read_csv('processed_data.csv')

# %%
#Overview of the dataset
df.head()
# Out:
#                                                  url  \
# 0  https://www.mycareersfuture.gov.sg/job/custome...
# 1  https://www.mycareersfuture.gov.sg/job/enginee...
# 2  https://www.mycareersfuture.gov.sg/job/sales/b...
# 3  https://www.mycareersfuture.gov.sg/job/banking...
# 4  https://www.mycareersfuture.gov.sg/job/archite...
#
#                                            job_title  \
# 0                         PRODUCTION CONTROL MANAGER
# 1       Design Engineer ( Mechanical  /  Electrical)
# 2                     Business Development Executive
# 3                            Senior / Data Scientist
# 4  8890-Sales Consultant [ Digital Software| Saas...
#
#                                     description_html  \
# 0  <p><strong>JOB DESCIPTION</strong></p>\n<ul>\n...
# 1  <p><strong>SUMMARY</strong></p>\n<ul>\n  <li>T...
# 2  <p><strong>Job description</strong></p>\n<p>Wh...
# 3  <p>The ideal candidate should have a good unde...
# 4  <p><strong>Sales Consultant (Digital Software)...
#
#                                          description              job_type  \
# 0  JOB DESCIPTION\n\n  planning and organising pr...  Permanent, Full Time
# 1  SUMMARY\n\n  This      position is responsible...             Full Time
# 2  Job description\nWho we are:\nWe are a logisti...  Part Time, Permanent
# 3  The ideal candidate should have a good underst...  Permanent, Full Time
# 4  Sales Consultant (Digital Software)\nLocation:...  Permanent, Full Time
#
#                                              company  \
# 0                              Snl Logistics Pte Ltd
# 1  Jamco Aero Design &Amp; Engineering Private Li...
# 2                             Airpak Express Pte Ltd
# 3                         Singapore Exchange Limited
# 4                  The Supreme Hr Advisory Pte. Ltd.
#
#                                             location  \
# 0                               31 GUL CIRCLE 629569
# 1                                          Singapore
# 2  TECHPLAS INDUSTRIAL BUILDING, 45 CHANGI SOUTH ...
# 3                 SGX CENTRE I, 2 SHENTON WAY 068804
# 4                SHENTON HOUSE, 3 SHENTON WAY 068805
#
#                                   description_tokens  \
# 0  ['job', 'descipt', 'plan', 'organis', 'product...
# 1  ['summari', 'posit', 'respons', 'support', 'pr...
# 2  ['job', 'descript', 'logist', 'servic', 'provi...
# 3  ['ideal', 'candid', 'good', 'understand', 'bus...
# 4  ['sale', 'consult', 'digit', 'softwar', 'locat...
#
#                                    description_clean  \
# 0  job desciption planning organising production ...
# 1  summary position responsible supporting projec...
# 2  job description logistics service provider sol...
# 3  ideal candidate good understanding business do...
# 4  sales consultant digital software location jal...
#
#                                     full_info_tokens  \
# 0  ['product', 'control', 'manag', 'snl', 'logist...
# 1  ['design', 'engin', 'mechan', 'electr', 'jamco...
# 2  ['busi', 'develop', 'execut', 'airpak', 'expre...
# 3  ['senior', 'data', 'scientist', 'singapor', 'e...
# 4  ['8890', 'sale', 'consult', 'digit', 'softwar'...
#
#                                      full_info_clean  duplicated  min_pay  \
# 0  production control manager snl logistics pte l...       False   2000.0
# 1  design engineer mechanical electrical jamco ae...       False   2500.0
# 2  business development executive airpak express ...       False   3200.0
# 3  senior data scientist singapore exchange limit...       False   9000.0
# 4  8890 sales consultant digital software saas in...       False   3000.0
#
#    max_pay
# 0   3400.0
# 1   4500.0
# 2   3500.0
# 3  14000.0
# 4   4500.0

# %%
#Using count vectorizer to obtain term frequencies for each document in "description_clean" column
#min_df, which dictates the minimum number of times a word must occur is set at 80 as most words that occur less than 80 times were junk words.
vectorizer = CountVectorizer(min_df=80)
X = vectorizer.fit_transform(df['description_clean'])

# %%
#Use this function to check each word and its frequency.
word_list = vectorizer.get_feature_names_out()
count_list = X.toarray().sum(axis=0)
word_dict = dict(zip(word_list,count_list))
{k: v for k, v in sorted(word_dict.items(), key=lambda item: item[1])}
# Out:
# {'dozen': 80,
#  'additionally': 81,
#  'amongst': 81,
#  'incentives': 81,
#  'pandas': 81,
#  'consented': 82,
#  'fostering': 82,
#  'producing': 82,
#  'autonomy': 83,
#  'confident': 83,
#  'easy': 83,
#  'eligibility': 83,
#  'http': 83,
#  'initiate': 83,
#  'majority': 83,
#  'professionally': 83,
#  'question': 83,
#  'unless': 83,
#  'disclosure': 84,
#  'evolution': 84,
#  'inputs': 84,
#  'offered': 84,
#  'spans': 84,
#  'still': 84,
#  'tomorrow': 84,
#  'withdraw': 84,
#  'apart': 85,
#  'away': 85,
#  'commensurate': 85,
#  'documentations': 85,
#  'ever': 85,
#  'html5': 85,
#  'initial': 85,
#  'majors': 85,
#  'respected': 85,
#  'seeks': 85,
#  'achieving': 86,
#  'cleansing': 86,
#  'collective': 86,
#  'eco': 86,
#  'instead': 86,
#  'intellectual': 86,
#  'minded': 86,
#  'actual': 87,
#  'competency': 87,
#  'grasp': 87,
#  'guiding': 87,
#  'style': 87,
#  'behind': 88,
#  'consolidate': 88,
#  'demonstrable': 88,
#  'ineligible': 88,
#  'medically': 88,
#  'quo': 88,
#  'resso': 88,
#  '80': 89,
#  'delight': 89,
#  'fulfil': 89,
#  'launched': 89,
#  'marketplace': 89,
#  'regularly': 89,
#  'stored': 89,
#  'allows': 90,
#  'connectivity': 90,
#  'emphasis': 90,
#  'externally': 90,
#  'integral': 90,
#  'mumbai': 90,
#  'reason': 90,
#  'strict': 90,
#  'versed': 90,
#  'acknowledge': 91,
#  'created': 91,
#  'differentiated': 91,
#  'disclose': 91,
#  'enthusiasm': 91,
#  'excited': 91,
#  'governments': 91,
#  'interpretation': 91,
#  'participation': 91,
#  'preferable': 91,
#  'putting': 91,
#  'ranging': 91,
#  'supervise': 91,
#  'typescript': 91,
#  'citigroup': 92,
#  'educational': 92,
#  'interviews': 92,
#  'meets': 92,
#  'method': 92,
#  'overseeing': 92,
#  'spanning': 92,
#  'thank': 92,
#  'boot': 93,
#  'brings': 93,
#  'champion': 93,
#  'clustering': 93,
#  'generating': 93,
#  'instructions': 93,
#  'parts': 93,
#  'pattern': 93,
#  'road': 93,
#  'story': 93,
#  'amounts': 94,
#  'automating': 94,
#  'competitors': 94,
#  'confluence': 94,
#  'creates': 94,
#  'dive': 94,
#  'enterprises': 94,
#  'kpi': 94,
#  'mitigation': 94,
#  'proposal': 94,
#  'rolling': 94,
#  'truly': 94,
#  'achievement': 95,
#  'alternative': 95,
#  'authority': 95,
#  'beneficial': 95,
#  'broader': 95,
#  'eager': 95,
#  'embedding': 95,
#  'inc': 95,
#  'liaison': 95,
#  'offline': 95,
#  'paid': 95,
#  'streams': 95,
#  'targeted': 95,
#  'verify': 95,
#  '200': 96,
#  'advise': 96,
#  'concerns': 96,
#  'nice': 96,
#  'operates': 96,
#  'orchestration': 96,
#  'os': 96,
#  'yet': 96,
#  'continually': 97,
#  'detect': 97,
#  'engines': 97,
#  'files': 97,
#  'pain': 97,
#  'proposed': 97,
#  'requisition': 97,
#  'collected': 98,
#  'five': 98,
#  'invited': 98,
#  'postgresql': 98,
#  'promoting': 98,
#  'break': 99,
#  'combined': 99,
#  'costs': 99,
#  'draw': 99,
#  'eligible': 99,
#  'interactive': 99,
#  'prototyping': 99,
#  'raise': 99,
#  'speaking': 99,
#  'xml': 99,
#  'consistency': 100,
#  'disciplinary': 100,
#  'enquiries': 100,
#  'grade': 100,
#  'guided': 100,
#  'impacts': 100,
#  'limits': 100,
#  'map': 100,
#  'maximize': 100,
#  'sme': 100,
#  '00pm': 101,
#  'bold': 101,
#  'connected': 101,
#  'debug': 101,
#  'hong': 101,
#  'invest': 101,
#  'pregnancy': 101,
#  'pro': 101,
#  'recovery': 101,
#  'sensitive': 101,
#  'db': 102,
#  'deployed': 102,
#  'evidence': 102,
#  'matlab': 102,
#  'phone': 102,
#  'possesses': 102,
#  'possibilities': 102,
#  'streamline': 102,
#  'consumption': 103,
#  'efficiencies': 103,
#  'express': 103,
#  'holistic': 103,
#  'macro': 103,
#  'medium': 103,
#  'numbers': 103,
#  'posting': 103,
#  'upgrades': 103,
#  '30am': 104,
#  'approved': 104,
#  'conversion': 104,
#  'golang': 104,
#  'led': 104,
#  'limit': 104,
#  'priority': 104,
#  'scaling': 104,
#  'selected': 104,
#  'society': 104,
#  'timeline': 104,
#  'traditional': 104,
#  'utmost': 104,
#  'win': 104,
#  'ambitions': 105,
#  'buy': 105,
#  'consultancy': 105,
#  'less': 105,
#  'onsite': 105,
#  'peer': 105,
#  'pride': 105,
#  'prioritise': 105,
#  'proprietary': 105,
#  'represent': 105,
#  'south': 105,
#  'accountable': 106,
#  'continues': 106,
#  'diligence': 106,
#  'empowered': 106,
#  'immediate': 106,
#  'instances': 106,
#  'intermediate': 106,
#  'liaising': 106,
#  'optimisation': 106,
#  'players': 106,
#  'specialists': 106,
#  '2012': 107,
#  'adopt': 107,
#  'assessing': 107,
#  'attributes': 107,
#  'cycles': 107,
#  'display': 107,
#  'energetic': 107,
#  'indonesia': 107,
#  'merit': 107,
#  'mongodb': 107,
#  'much': 107,
#  'news': 107,
#  'node': 107,
#  'phase': 107,
#  'representative': 107,
#  'resilience': 107,
#  'theory': 107,
#  'vb': 107,
#  'balanced': 108,
#  'confidentiality': 108,
#  'consider': 108,
#  'defect': 108,
#  'demands': 108,
#  'employers': 108,
#  'might': 108,
#  'qlik': 108,
#  'raw': 108,
#  'restful': 108,
#  'segment': 108,
#  'situations': 108,
#  'speed': 108,
#  'stock': 108,
#  'uncover': 108,
#  'wider': 108,
#  'connecting': 109,
#  'effort': 109,
#  'rich': 109,
#  'roadmaps': 109,
#  'safeguarding': 109,
#  'superior': 109,
#  'answer': 110,
#  'disclosing': 110,
#  'eeo': 110,
#  'experimentation': 110,
#  'file': 110,
#  'li': 110,
#  'obtain': 110,
#  'participating': 110,
#  'profit': 110,
#  'recognises': 110,
#  's3': 110,
#  'second': 110,
#  'sites': 110,
#  'stages': 110,
#  '14': 111,
#  'exploration': 111,
#  'malaysia': 111,
#  'multinational': 111,
#  'possibility': 111,
#  'recent': 111,
#  'spectrum': 111,
#  'whole': 111,
#  'amazon': 112,
#  'escalation': 112,
#  'optimise': 112,
#  'rate': 112,
#  'saas': 112,
#  'sectors': 112,
#  'utilize': 112,
#  'complexity': 113,
#  'custom': 113,
#  'expansion': 113,
#  'launches': 113,
#  'math': 113,
#  'mobility': 113,
#  'semiconductor': 113,
#  'sure': 113,
#  'uses': 113,
#  'zones': 113,
#  '35': 114,
#  'allowance': 114,
#  'ba': 114,
#  'bringing': 114,
#  'contributes': 114,
#  'escalating': 114,
#  'exploring': 114,
#  'giving': 114,
#  'ip': 114,
#  'json': 114,
#  'retention': 114,
#  'systematic': 114,
#  'times': 114,
#  'treated': 114,
#  'updating': 114,
#  'adhere': 115,
#  'dealing': 115,
#  'erp': 115,
#  'fluent': 115,
#  'github': 115,
#  'hard': 115,
#  'lean': 115,
#  'moving': 115,
#  'output': 115,
#  'thinker': 115,
#  'cleaning': 116,
#  'comes': 116,
#  'contributor': 116,
#  'fair': 116,
#  'proud': 116,
#  'title': 116,
#  'touch': 116,
#  'agenda': 117,
#  'box': 117,
#  'discover': 117,
#  'duration': 117,
#  'solutioning': 117,
#  'acquire': 118,
#  'builds': 118,
#  'coach': 118,
#  'confidential': 118,
#  'discuss': 118,
#  'enthusiastic': 118,
#  'example': 118,
#  'feasibility': 118,
#  'finding': 118,
#  'involvement': 118,
#  'phases': 118,
#  'regulators': 118,
#  'copy': 119,
#  'firms': 119,
#  'forms': 119,
#  'ground': 119,
#  'push': 119,
#  'qlikview': 119,
#  'submission': 119,
#  'delivers': 120,
#  'pl': 120,
#  'roll': 120,
#  'scheduling': 120,
#  'startup': 120,
#  'europe': 121,
#  'financing': 121,
#  'formal': 121,
#  'institutional': 121,
#  'reviewed': 121,
#  'supervisor': 121,
#  'translating': 121,
#  'geographies': 122,
#  'indicators': 122,
#  'outcome': 122,
#  'peers': 122,
#  'positioning': 122,
#  'sending': 122,
#  'abreast': 123,
#  'asp': 123,
#  'demonstrating': 123,
#  'empowers': 123,
#  'happen': 123,
#  'micro': 123,
#  'relations': 123,
#  'useful': 123,
#  'audits': 124,
#  'bachelors': 124,
#  'comply': 124,
#  'documenting': 124,
#  'feel': 124,
#  'focuses': 124,
#  'known': 124,
#  'oversight': 124,
#  'promise': 124,
#  'vitae': 124,
#  'accelerate': 125,
#  'affirmative': 125,
#  'appropriately': 125,
#  'compelling': 125,
#  'designers': 125,
#  'items': 125,
#  'reusable': 125,
#  'admin': 126,
#  'advocate': 126,
#  'assignments': 126,
#  'button': 126,
#  'fri': 126,
#  'located': 126,
#  'organisational': 126,
#  'referral': 126,
#  'thorough': 126,
#  'welcoming': 126,
#  'engagements': 127,
#  'enhancing': 127,
#  'equities': 127,
#  'ethical': 127,
#  'valuable': 127,
#  'adhering': 128,
#  'backgrounds': 128,
#  'chance': 128,
#  'count': 128,
#  'economy': 128,
#  'influencing': 128,
#  'investigate': 128,
#  'transforming': 128,
#  'adherence': 129,
#  'america': 129,
#  'approval': 129,
#  'discriminate': 129,
#  'ethics': 129,
#  'forums': 129,
#  'going': 129,
#  'innovations': 129,
#  'input': 129,
#  'invites': 129,
#  'list': 129,
#  'nimble': 129,
#  'novel': 129,
#  'screening': 129,
#  'solver': 129,
#  'studio': 129,
#  'turn': 129,
#  'wholesale': 129,
#  'worked': 129,
#  'adecco': 130,
#  'aims': 130,
#  'executives': 130,
#  'involves': 130,
#  'link': 130,
#  'particularly': 130,
#  'profitability': 130,
#  'publish': 130,
#  'respect': 130,
#  'adaptable': 131,
#  'combination': 131,
#  'contracts': 131,
#  'courses': 131,
#  'involving': 131,
#  'milestones': 131,
#  'mon': 131,
#  'performs': 131,
#  'regardless': 131,
#  'regions': 131,
#  'shared': 131,
#  'airflow': 132,
#  'capable': 132,
#  'codes': 132,
#  'course': 132,
#  'enrich': 132,
#  'establishing': 132,
#  'healthy': 132,
#  'integrating': 132,
#  'interview': 132,
#  'maximum': 132,
#  'microservices': 132,
#  'pm': 132,
#  'prototype': 132,
#  'rapid': 132,
#  'several': 132,
#  'since': 132,
#  'adobe': 133,
#  'mandatory': 133,
#  'protocols': 133,
#  'sex': 133,
#  '15': 134,
#  '50': 134,
#  'definition': 134,
#  'discussion': 134,
#  'exercise': 134,
#  'negotiation': 134,
#  'north': 134,
#  'officer': 134,
#  'ph': 134,
#  'primarily': 134,
#  'remotely': 134,
#  'resolving': 134,
#  'skilled': 134,
#  'accurately': 135,
#  'chinese': 135,
#  'compensation': 135,
#  'condition': 135,
#  'derive': 135,
#  'desk': 135,
#  'discovery': 135,
#  'implementations': 135,
#  'manages': 135,
#  'segments': 135,
#  'threats': 135,
#  'aptitude': 136,
#  'closing': 136,
#  'completed': 136,
#  'demonstrates': 136,
#  'free': 136,
#  'implemented': 136,
#  'periodic': 136,
#  'reduce': 136,
#  'suppliers': 136,
#  'upon': 136,
#  'hold': 137,
#  'presenting': 137,
#  'put': 137,
#  'behaviours': 138,
#  'money': 138,
#  'servers': 138,
#  'special': 138,
#  'statements': 138,
#  'store': 138,
#  'total': 138,
#  'board': 139,
#  'bs': 139,
#  'funds': 139,
#  'ingestion': 139,
#  'makes': 139,
#  'reviewing': 139,
#  'rewards': 139,
#  'add': 140,
#  'angular': 140,
#  'contributing': 140,
#  'joining': 140,
#  'powerbi': 140,
#  'communicator': 141,
#  'coordinating': 141,
#  'hear': 141,
#  'resumes': 141,
#  'someone': 141,
#  'strengths': 141,
#  'traders': 141,
#  'version': 141,
#  'coaching': 142,
#  'expression': 142,
#  'final': 142,
#  'investigations': 142,
#  'recognized': 142,
#  'simulation': 142,
#  'transport': 142,
#  'understood': 142,
#  'voice': 142,
#  'calls': 143,
#  'cultural': 143,
#  'disabilities': 143,
#  'frontend': 143,
#  'impactful': 143,
#  'installation': 143,
#  'modules': 143,
#  'schedules': 143,
#  'shift': 143,
#  'specifically': 143,
#  'wish': 143,
#  'accommodation': 144,
#  'attend': 144,
#  'drivers': 144,
#  'supported': 144,
#  'accommodations': 145,
#  'advantages': 145,
#  'identified': 145,
#  'communicating': 146,
#  'corporations': 146,
#  'formulate': 146,
#  'fundamentals': 146,
#  'hand': 146,
#  'investigation': 146,
#  'jenkins': 146,
#  'remote': 146,
#  'architectural': 147,
#  'eye': 147,
#  'kpis': 147,
#  'past': 147,
#  'segmentation': 147,
#  'smooth': 147,
#  'star': 147,
#  'concise': 148,
#  'ensures': 148,
#  'optimal': 148,
#  'transparency': 148,
#  'letter': 149,
#  'ops': 149,
#  'reconciliation': 149,
#  'another': 150,
#  'environmental': 150,
#  'ios': 150,
#  'owner': 150,
#  'reputation': 150,
#  'ups': 150,
#  'charge': 151,
#  'focusing': 151,
#  'interns': 151,
#  'let': 151,
#  'prototypes': 151,
#  'publication': 151,
#  'quant': 151,
#  'steps': 151,
#  'succeed': 151,
#  'apps': 152,
#  'conditions': 152,
#  'functionality': 152,
#  'fundamental': 152,
#  'history': 152,
#  'marital': 152,
#  'mark': 152,
#  'respective': 152,
#  'warehousing': 152,
#  '9am': 153,
#  'context': 153,
#  'match': 153,
#  'recruiting': 153,
#  'resourceful': 153,
#  'three': 153,
#  'classes': 154,
#  'confidence': 154,
#  'side': 154,
#  'ambiguity': 155,
#  'east': 155,
#  'factors': 155,
#  'principal': 155,
#  'qa': 155,
#  'rates': 155,
#  'serving': 155,
#  '6pm': 156,
#  'command': 156,
#  'ecommerce': 156,
#  'escalate': 156,
#  'price': 156,
#  'regard': 156,
#  'seek': 156,
#  'selection': 156,
#  'step': 156,
#  'verification': 156,
#  'ambitious': 157,
#  'clean': 157,
#  'consumers': 157,
#  'funding': 157,
#  'resilient': 157,
#  'asian': 158,
#  'audience': 158,
#  'capture': 158,
#  'explain': 158,
#  'interests': 158,
#  'organize': 158,
#  'regression': 158,
#  'workshops': 158,
#  'cause': 159,
#  'headquartered': 159,
#  'incidents': 159,
#  'maintains': 159,
#  'technological': 159,
#  'transfer': 159,
#  'acumen': 160,
#  'advice': 160,
#  'amount': 160,
#  'cover': 160,
#  'forefront': 160,
#  'move': 160,
#  'pay': 160,
#  'valuation': 160,
#  'spirit': 161,
#  'architects': 162,
#  'delivered': 162,
#  'entrepreneurial': 162,
#  'income': 162,
#  'judgment': 162,
#  'nature': 162,
#  'neural': 162,
#  'portfolios': 162,
#  'progression': 162,
#  'clinical': 163,
#  'perspective': 163,
#  'affiliates': 164,
#  'android': 164,
#  'message': 164,
#  'proposals': 164,
#  'subsidiaries': 164,
#  'timelines': 164,
#  'undertake': 164,
#  'designed': 165,
#  'identification': 165,
#  'masters': 165,
#  'million': 165,
#  'prospective': 165,
#  'train': 165,
#  'whether': 165,
#  'achievements': 166,
#  'deal': 166,
#  'extraction': 166,
#  'institute': 166,
#  'advertising': 167,
#  'morgan': 167,
#  'outside': 167,
#  'parties': 167,
#  'quick': 167,
#  'centric': 168,
#  'develops': 168,
#  'domains': 168,
#  'experiments': 168,
#  'mentoring': 168,
#  'single': 168,
#  'successfully': 168,
#  'third': 168,
#  'checks': 169,
#  'interfaces': 169,
#  'messaging': 169,
#  'workforce': 169,
#  'analysing': 170,
#  'curious': 170,
#  'interpret': 170,
#  'lake': 170,
#  'simple': 170,
#  'topics': 170,
#  'celebrating': 171,
#  'css': 171,
#  'enables': 171,
#  'options': 171,
#  'accept': 172,
#  'hope': 172,
#  'keeping': 172,
#  'millions': 172,
#  '3d': 173,
#  'debugging': 173,
#  'devices': 173,
#  'executing': 173,
#  'interactions': 173,
#  'preparing': 173,
#  'reflects': 173,
#  'respond': 173,
#  'stage': 173,
#  '20': 174,
#  '65': 174,
#  'applicant': 174,
#  'enhancement': 174,
#  'informed': 174,
#  'mandarin': 174,
#  'pursuing': 174,
#  'tier': 174,
#  'traffic': 174,
#  'united': 174,
#  'vba': 174,
#  'holder': 175,
#  'mathematical': 175,
#  'mnc': 175,
#  'stress': 175,
#  'load': 176,
#  'offerings': 176,
#  'director': 177,
#  'institution': 177,
#  'measure': 177,
#  'remuneration': 177,
#  'voices': 177,
#  'accountability': 178,
#  'ads': 178,
#  'check': 178,
#  'continue': 178,
#  'discussions': 178,
#  'evaluating': 178,
#  'satisfaction': 178,
#  'minimal': 179,
#  'never': 179,
#  'strongly': 179,
#  'student': 179,
#  'audiences': 180,
#  'encouraged': 180,
#  'internally': 180,
#  'met': 180,
#  'qualitative': 180,
#  'billion': 181,
#  'graduates': 181,
#  'jira': 181,
#  'middle': 181,
#  'sessions': 181,
#  'assessments': 182,
#  'drives': 182,
#  'flows': 182,
#  'fraud': 182,
#  'fresh': 182,
#  'interaction': 182,
#  'journals': 182,
#  'physics': 182,
#  'stability': 182,
#  'alignment': 183,
#  'incident': 183,
#  'mitigate': 183,
#  'ntu': 184,
#  'provider': 184,
#  'agree': 185,
#  'collecting': 185,
#  'enabling': 185,
#  'expect': 185,
#  'migration': 185,
#  'particular': 185,
#  'encourage': 186,
#  'fellow': 186,
#  'liquidity': 186,
#  'onboarding': 186,
#  'programmes': 186,
#  'behavior': 187,
#  'embedded': 187,
#  'flexibility': 187,
#  'submitting': 187,
#  'validate': 187,
#  'classification': 188,
#  'economic': 188,
#  'packages': 188,
#  'performed': 188,
#  'publications': 188,
#  'return': 188,
#  'weekly': 188,
#  '30': 189,
#  'engine': 189,
#  'event': 189,
#  'everything': 189,
#  'exchange': 189,
#  'gcp': 189,
#  'mapping': 189,
#  'types': 189,
#  'whatsapp': 189,
#  'assistant': 190,
#  'brands': 190,
#  'offering': 190,
#  'quarterly': 190,
#  'relating': 190,
#  'series': 190,
#  'id': 191,
#  'root': 191,
#  'talents': 191,
#  'defined': 192,
#  'innovate': 192,
#  'partnerships': 193,
#  'rapidly': 193,
#  'result': 193,
#  'benefit': 194,
#  'dedicated': 194,
#  'eg': 194,
#  'engaging': 194,
#  'nosql': 194,
#  'setup': 194,
#  'specification': 194,
#  'addition': 195,
#  'give': 195,
#  'visualisation': 195,
#  'align': 196,
#  'connects': 196,
#  'fluency': 196,
#  'providers': 196,
#  'reference': 196,
#  'response': 196,
#  'early': 197,
#  'involve': 197,
#  'mind': 197,
#  'aligned': 198,
#  'entire': 198,
#  'expand': 198,
#  'hire': 198,
#  'mechanical': 198,
#  'native': 198,
#  'coverage': 199,
#  'distribution': 199,
#  'logical': 199,
#  'specialist': 199,
#  'virtual': 199,
#  'helps': 200,
#  'material': 200,
#  'stay': 200,
#  'aim': 201,
#  'fintech': 201,
#  'hybrid': 201,
#  'articulate': 202,
#  'deemed': 202,
#  'expanding': 202,
#  'react': 202,
#  'targets': 202,
#  'text': 202,
#  'tuning': 202,
#  'certifications': 203,
#  'china': 203,
#  'determine': 203,
#  'issue': 203,
#  'oversee': 203,
#  'securities': 204,
#  'agreed': 205,
#  'efficiently': 205,
#  'even': 205,
#  'html': 205,
#  'worldwide': 205,
#  'consistent': 206,
#  'defining': 206,
#  'desire': 206,
#  'owners': 206,
#  'undergraduate': 206,
#  'evolving': 207,
#  'food': 207,
#  'graph': 207,
#  'presence': 207,
#  'sciences': 207,
#  'workflows': 207,
#  'consultants': 208,
#  'heart': 208,
#  'js': 208,
#  'regarding': 208,
#  'release': 208,
#  'troubleshoot': 208,
#  'ambition': 209,
#  'among': 209,
#  'completion': 209,
#  'construction': 209,
#  'facilities': 209,
#  'objective': 209,
#  'reasonable': 209,
#  'unstructured': 209,
#  'adapt': 210,
#  'allow': 210,
#  'friday': 210,
#  'learner': 210,
#  'pursue': 210,
#  'collaboratively': 211,
#  'crm': 211,
#  'friendly': 211,
#  'month': 211,
#  'optimizing': 211,
#  'procurement': 211,
#  'willingness': 211,
#  'previous': 212,
#  'lines': 213,
#  'managed': 213,
#  'advance': 214,
#  'assisting': 214,
#  'logistics': 214,
#  'researchers': 214,
#  'scripts': 214,
#  'suitable': 214,
#  'deploying': 215,
#  'tight': 215,
#  'advisory': 216,
#  'embrace': 216,
#  'spring': 216,
#  'stories': 216,
#  'wealth': 216,
#  'activity': 217,
#  'curiosity': 217,
#  'gaps': 217,
#  'highest': 217,
#  'organizations': 217,
#  'reliable': 217,
#  '100': 218,
#  'either': 218,
#  'forecasting': 218,
#  'mysql': 218,
#  'proper': 218,
#  'query': 218,
#  'sourcing': 218,
#  'strive': 218,
#  'batch': 219,
#  'designs': 219,
#  'apache': 220,
#  'could': 220,
#  'monday': 220,
#  'organized': 220,
#  'ready': 220,
#  'statement': 220,
#  'terms': 220,
#  'type': 220,
#  'volume': 220,
#  'call': 221,
#  'certified': 221,
#  'computational': 221,
#  'consistently': 221,
#  'curriculum': 221,
#  'mentor': 221,
#  'dashboard': 222,
#  'desired': 222,
#  'fund': 222,
#  'treasury': 222,
#  'banks': 223,
#  'ideally': 223,
#  'developments': 224,
#  ...}

# %%
#Cluster the job description into 20 clusters using LDA model
#The number of clusters was determined by observing for overlaps in key terms between topics, which would indicated that number of topics was too high
num_topics = 20
lda = LatentDirichletAllocation(n_components=num_topics, max_iter=5, learning_method='online',random_state=0, verbose =1).fit(X)
# Out:
# iteration: 1 of max_iter: 5
# iteration: 2 of max_iter: 5
# iteration: 3 of max_iter: 5
# iteration: 4 of max_iter: 5
# iteration: 5 of max_iter: 5

# %%
#transform the matrix of term frequencies into a list of probabilities for each topic
transformed = lda.transform(X)

# %%
transformed.shape
# Out:
# (6243, 20)

# %%
#function to display the key words for each topic
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print (f"Topic:{topic_idx}")
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
#display the top 20 terms for each cluster
display_topics(lda,vectorizer.get_feature_names_out(),20)
# Out:
# Topic:0
# research singapore students nus covid job internship staff may health 19 candidates university 2022 vaccinated successful information roles applicants campus
# Topic:1
# operations delivery ensure quality technology environment manage group processes production supply management operational healthcare bank control chain work innovation supports
# Topic:2
# risk credit financial market trading management investment finance quantitative portfolio models asset trade markets capital experience including role model products
# Topic:3
# support assist management reports job data perform ad duties ensure prepare assigned office hoc related provide review system required daily
# Topic:4
# sales customer customers product technical center new service solutions products account partners company solution existing revenue key experience services opportunities
# Topic:5
# clients client business financial global services management team banking experience technology compliance service work bank across program control skills firm
# Topic:6
# security management google party events cyber etc line including facilities incident certified support knowledge media working ensure third incidents activities
# Topic:7
# experience software development design systems engineering knowledge team applications architecture web code programming working computer develop technical using technologies services
# Topic:8
# com ea please candidates apply resume data pte ltd shortlisted personal job privacy us sg interested application notified email send
# Topic:9
# business data management analytics analysis stakeholders reporting experience support key risk insights tools analytical requirements governance processes conduct bi drive
# Topic:10
# product business marketing team experience products teams market digital management drive across work strategy working new key strong ability develop
# Topic:11
# project requirements testing experience test business system development design technical support user ensure work functional knowledge management solutions application solution
# Topic:12
# tiktok inspire team creativity mission bring global including joy video platform qualifications bytedance leading responsibilities committed creating users experience people
# Topic:13
# research computer engineering experience science development vision learning job programming related python requirements machine develop knowledge degree systems software responsibilities
# Topic:14
# skills work ability team strong communication able good excellent experience analytical knowledge written analysis environment problem self solving interpersonal player
# Topic:15
# data experience analytics science big sql solutions python tools business build engineering using platform pipelines working models large technical years
# Topic:16
# learning ai machine ml algorithms language deep natural processing related models artificial research intelligence nlp skills computing areas one mining
# Topic:17
# job work working training experience support equipment software diploma good requirements days hr system team relevant salary company systems engineering
# Topic:18
# work us world people team make opportunity help technology culture best company role part build working global skills one singapore
# Topic:19
# cloud experience end solutions technologies technical technology platform java development infrastructure application database services team network sap ai azure integration

# %%
#produce a column denoting which cluster each job description belongs to
arg_max = [np.where(i==max(i))[0][0] for i in transformed]
df['cluster'] = arg_max

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.mycareersfuture.gov.sg/job/custome...
# 1  https://www.mycareersfuture.gov.sg/job/enginee...
# 2  https://www.mycareersfuture.gov.sg/job/sales/b...
# 3  https://www.mycareersfuture.gov.sg/job/banking...
# 4  https://www.mycareersfuture.gov.sg/job/archite...
#
#                                            job_title  \
# 0                         PRODUCTION CONTROL MANAGER
# 1       Design Engineer ( Mechanical  /  Electrical)
# 2                     Business Development Executive
# 3                            Senior / Data Scientist
# 4  8890-Sales Consultant [ Digital Software| Saas...
#
#                                     description_html  \
# 0  <p><strong>JOB DESCIPTION</strong></p>\n<ul>\n...
# 1  <p><strong>SUMMARY</strong></p>\n<ul>\n  <li>T...
# 2  <p><strong>Job description</strong></p>\n<p>Wh...
# 3  <p>The ideal candidate should have a good unde...
# 4  <p><strong>Sales Consultant (Digital Software)...
#
#                                          description              job_type  \
# 0  JOB DESCIPTION\n\n  planning and organising pr...  Permanent, Full Time
# 1  SUMMARY\n\n  This      position is responsible...             Full Time
# 2  Job description\nWho we are:\nWe are a logisti...  Part Time, Permanent
# 3  The ideal candidate should have a good underst...  Permanent, Full Time
# 4  Sales Consultant (Digital Software)\nLocation:...  Permanent, Full Time
#
#                                              company  \
# 0                              Snl Logistics Pte Ltd
# 1  Jamco Aero Design &Amp; Engineering Private Li...
# 2                             Airpak Express Pte Ltd
# 3                         Singapore Exchange Limited
# 4                  The Supreme Hr Advisory Pte. Ltd.
#
#                                             location  \
# 0                               31 GUL CIRCLE 629569
# 1                                          Singapore
# 2  TECHPLAS INDUSTRIAL BUILDING, 45 CHANGI SOUTH ...
# 3                 SGX CENTRE I, 2 SHENTON WAY 068804
# 4                SHENTON HOUSE, 3 SHENTON WAY 068805
#
#                                   description_tokens  \
# 0  ['job', 'descipt', 'plan', 'organis', 'product...
# 1  ['summari', 'posit', 'respons', 'support', 'pr...
# 2  ['job', 'descript', 'logist', 'servic', 'provi...
# 3  ['ideal', 'candid', 'good', 'understand', 'bus...
# 4  ['sale', 'consult', 'digit', 'softwar', 'locat...
#
#                                    description_clean  \
# 0  job desciption planning organising production ...
# 1  summary position responsible supporting projec...
# 2  job description logistics service provider sol...
# 3  ideal candidate good understanding business do...
# 4  sales consultant digital software location jal...
#
#                                     full_info_tokens  \
# 0  ['product', 'control', 'manag', 'snl', 'logist...
# 1  ['design', 'engin', 'mechan', 'electr', 'jamco...
# 2  ['busi', 'develop', 'execut', 'airpak', 'expre...
# 3  ['senior', 'data', 'scientist', 'singapor', 'e...
# 4  ['8890', 'sale', 'consult', 'digit', 'softwar'...
#
#                                      full_info_clean  duplicated  min_pay  \
# 0  production control manager snl logistics pte l...       False   2000.0
# 1  design engineer mechanical electrical jamco ae...       False   2500.0
# 2  business development executive airpak express ...       False   3200.0
# 3  senior data scientist singapore exchange limit...       False   9000.0
# 4  8890 sales consultant digital software saas in...       False   3000.0
#
#    max_pay  cluster
# 0   3400.0        1
# 1   4500.0       14
# 2   3500.0       14
# 3  14000.0        9
# 4   4500.0       14

# %%
#Checking the distribution of the clusters
df['cluster'].value_counts()
# Out:
# 10    757
# 15    649
# 18    633
# 7     608
# 9     507
# 11    433
# 8     360
# 13    343
# 14    325
# 3     322
# 17    270
# 12    268
# 5     254
# 0     159
# 2     145
# 1      70
# 19     48
# 16     43
# 4      30
# 6      19
# Name: cluster, dtype: int64

# %%
#Filtering jobs by clusters to determine a hypothesized cluster
df[df['cluster']==2].sample(5)
# Out:
#                                                     url  \
# 763   https://www.mycareersfuture.gov.sg/job/banking...
# 5205  https://sg.jobsdb.com/job/Treasury-Analyst-4b7...
# 4251  https://sg.jobsdb.com/job/Market-Risk-Analyst-...
# 4097  https://sg.jobsdb.com/job/Wholesale-Model-4068...
# 24    https://www.mycareersfuture.gov.sg/job/banking...
#
#                                               job_title  \
# 763   Senior Associate, Front Office Quant, Quant &a...
# 5205                                   Treasury Analyst
# 4251  AVP, Market Risk Analyst, MRM – Risk Control &...
# 4097  VP, Wholesale Model Development, Risk Manageme...
# 24                                    Financial Analyst
#
#                                        description_html  \
# 763   <p><strong>Business Function</strong></p>\n<p>...
# 5205  <div class="-desktop-no-padding-top" id="job-d...
# 4251  <div class="-desktop-no-padding-top" id="job-d...
# 4097  <div class="-desktop-no-padding-top" id="job-d...
# 24    <p>EDHEC Singapore Infrastructure Investment I...
#
#                                             description   job_type  \
# 763   Business Function\nAs a leader in treasury ope...  Full Time
# 5205  \nIngenico has led the payment industry for mo...  Full time
# 4251  \nAVP, Market Risk Analyst, MRM – Risk Control...  Full time
# 4097  Business Functions\nRisk Management Group work...  Full time
# 24    EDHEC Singapore Infrastructure Investment Inst...  Permanent
#
#                                                 company  \
# 763                                       Dbs Bank Ltd.
# 5205                                 Ingenico ePayments
# 4251                                          OCBC Bank
# 4097                                           DBS Bank
# 24    Association Edhec Business School Singapore Br...
#
#                                        location  \
# 763                                   Singapore
# 5205                                  Singapore
# 4251                                  Singapore
# 4097                                  Singapore
# 24    ONE GEORGE STREET, 1 GEORGE STREET 049145
#
#                                      description_tokens  \
# 763   ['busi', 'function', 'leader', 'treasuri', 'op...
# 5205  ['ingenico', 'led', 'payment', 'industri', '30...
# 4251  ['avp', 'market', 'risk', 'analyst', 'mrm', 'r...
# 4097  ['busi', 'function', 'risk', 'manag', 'group',...
# 24    ['edhec', 'singapor', 'infrastructur', 'invest...
#
#                                       description_clean  \
# 763   business function leader treasury operations d...
# 5205  ingenico led payment industry 30 years become ...
# 4251  avp market risk analyst mrm risk control analy...
# 4097  business functions risk management group works...
# 24    edhec singapore infrastructure investment inst...
#
#                                        full_info_tokens  \
# 763   ['senior', 'associ', 'front', 'offic', 'quant'...
# 5205  ['treasuri', 'analyst', 'ingenico', 'epay', 'f...
# 4251  ['avp', 'market', 'risk', 'analyst', 'mrm', 'r...
# 4097  ['vp', 'wholesal', 'model', 'develop', 'risk',...
# 24    ['financi', 'analyst', 'associ', 'edhec', 'bus...
#
#                                         full_info_clean  duplicated  min_pay  \
# 763   senior associate front office quant quant amp ...       False   5000.0
# 5205  treasury analyst ingenico epayments full time ...       False      NaN
# 4251  avp market risk analyst mrm risk control analy...       False      NaN
# 4097  vp wholesale model development risk management...       False      NaN
# 24    financial analyst association edhec business s...       False   4000.0
#
#       max_pay  cluster
# 763    9000.0        2
# 5205      NaN        2
# 4251      NaN        2
# 4097      NaN        2
# 24     5000.0        2

# %% [markdown]
# Hypothesized Clusters
# <li>0: Research in AI/Data Science</li>
# <li>1: Production</li>
# <li>2: Analyst for Bank</li>
# <li>3: Unknown</li>
# <li>4: Sales</li>
# <li>5: Unknown</li>
# <li>6: Unknown</li>
# <li>7: Software Engineer</li>
# <li>8: Unknown</li>
# <li>9: Data Analyst</li>
# <li>10:Product Manager</li>
# <li>11: Unknown</li>
# <li>12: Openings in Tiktok</li>
# <li>13: Research in Data Science</li>
# <li>14: Unknown</li>
# <li>15: Data related roles</li>
# <li>16: AI/NLP related roles</li>
# <li>17: Unknown</li>
# <li>18: Unknown</li>
# <li>19: Cloud AI work</li>

# %% [markdown]
# ## Conclusion
# To conclude, we realised that most of the key terms for each topic were not skills, but rather other parts of the job description such as company information or day-to-day roles. Therefore, inputting skills to determine the closest cluster would yield very poor results. If there were methods to sieve out skills from these job descriptions, it would greatly improve the viability of such a recommender system. Furthermore, some clusters were difficult to identify. Nonetheless, we realise that this model can provide a useful function of generating key terms for each of these clusters, which might help with users who are crafting resumes, as resumes with key terms tend to get through automated systems better.

# %%
#Obtaining good clusters with well defined key terms
clusters = ["production", "bank analyst","sales", "software engineer","data analyst","product manager","data science research","ai and nlp","cloud ai"]
relevant_index =[1,2,4,7,9,10,13,16,19]

# %%
#Building a dataframe of job titles and key terms
result_dict={}
result_dict['title'] = clusters
key_terms=[]
for topic_idx, topic in enumerate(lda.components_):
    if topic_idx in relevant_index:
        key_terms.append([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-20 - 1:-1]])
result_dict['key_terms']=key_terms

result_df = pd.DataFrame(result_dict)

# %%
result_df.to_csv("key_terms.csv", index=False)
